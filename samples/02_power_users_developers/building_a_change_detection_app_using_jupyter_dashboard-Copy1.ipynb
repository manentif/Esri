# %% [markdown]
# # Building a change detection app using Jupyter Dashboard
#
# The Python API, along with the [Jupyter Dashboard](http://jupyter-dashboards-layout.readthedocs.io/) project enables Python developers to quickly build and prototype interactive web apps. This sample illustrates one such app which can be used to detect the changes in vegetation between the two dates. Increases in vegetation are shown in green, and decreases are shown in magenta.
#
# This sample uses the fast on-the-fly processing power of raster functions available in the `raster` module of the Python API.
#
# <blockquote>To run this sample you need `jupyter_dashboards` package in your conda environment. You can install it as shown below. For information on this, [refer to the install instructions](http://jupyter-dashboards-layout.readthedocs.io/en/latest/getting-started.html#installing-and-enabling)</blockquote>
#
#     conda install jupyter_dashboards -c conda-forge

# %%
conda install jupyter_dashboards -c conda-forge
# Out:
# Fetching package metadata ...............
# Solving package specifications: .
#
# Package plan for installation in environment C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection:
#
# The following NEW packages will be INSTALLED:
#
#     jupyter_dashboards: 0.7.0-py36_1000 conda-forge
#
# jupyter_dashbo   0% |                              | ETA:  --:--:--   0.00  B/s
# jupyter_dashbo   1% |                               | ETA:  0:00:00   6.58 MB/s
# jupyter_dashbo   3% |#                              | ETA:  0:00:04 431.95 kB/s
# jupyter_dashbo   5% |#                              | ETA:  0:00:03 493.35 kB/s
# jupyter_dashbo   6% |##                             | ETA:  0:00:02 648.14 kB/s
# jupyter_dashbo   8% |##                             | ETA:  0:00:02 660.68 kB/s
# jupyter_dashbo  10% |###                            | ETA:  0:00:02 605.58 kB/s
# jupyter_dashbo  12% |###                            | ETA:  0:00:02 637.74 kB/s
# jupyter_dashbo  13% |####                           | ETA:  0:00:02 724.83 kB/s
# jupyter_dashbo  15% |####                           | ETA:  0:00:02 704.82 kB/s
# jupyter_dashbo  17% |#####                          | ETA:  0:00:02 766.71 kB/s
# jupyter_dashbo  18% |#####                          | ETA:  0:00:01 839.47 kB/s
# jupyter_dashbo  20% |######                         | ETA:  0:00:01 872.30 kB/s
# jupyter_dashbo  22% |######                         | ETA:  0:00:01 869.40 kB/s
# jupyter_dashbo  24% |#######                        | ETA:  0:00:01 930.69 kB/s
# jupyter_dashbo  25% |#######                        | ETA:  0:00:01 957.33 kB/s
# jupyter_dashbo  27% |########                       | ETA:  0:00:01 985.11 kB/s
# jupyter_dashbo  29% |#########                      | ETA:  0:00:01   1.01 MB/s
# jupyter_dashbo  30% |#########                      | ETA:  0:00:01   1.02 MB/s
# jupyter_dashbo  32% |##########                     | ETA:  0:00:01   1.04 MB/s
# jupyter_dashbo  34% |##########                     | ETA:  0:00:01   1.10 MB/s
# jupyter_dashbo  36% |###########                    | ETA:  0:00:01   1.14 MB/s
# jupyter_dashbo  37% |###########                    | ETA:  0:00:01   1.15 MB/s
# jupyter_dashbo  39% |############                   | ETA:  0:00:00   1.18 MB/s
# jupyter_dashbo  41% |############                   | ETA:  0:00:00   1.21 MB/s
# jupyter_dashbo  42% |#############                  | ETA:  0:00:00   1.25 MB/s
# jupyter_dashbo  44% |#############                  | ETA:  0:00:00   1.27 MB/s
# jupyter_dashbo  46% |##############                 | ETA:  0:00:00   1.31 MB/s
# jupyter_dashbo  48% |##############                 | ETA:  0:00:00   1.35 MB/s
# jupyter_dashbo  49% |###############                | ETA:  0:00:00   1.38 MB/s
# jupyter_dashbo  51% |###############                | ETA:  0:00:00   1.41 MB/s
# jupyter_dashbo  53% |################               | ETA:  0:00:00   1.43 MB/s
# jupyter_dashbo  54% |#################              | ETA:  0:00:00   1.47 MB/s
# jupyter_dashbo  56% |#################              | ETA:  0:00:00   1.48 MB/s
# jupyter_dashbo  58% |##################             | ETA:  0:00:00   1.51 MB/s
# jupyter_dashbo  60% |##################             | ETA:  0:00:00   1.55 MB/s
# jupyter_dashbo  61% |###################            | ETA:  0:00:00   1.57 MB/s
# jupyter_dashbo  63% |###################            | ETA:  0:00:00   1.60 MB/s
# jupyter_dashbo  65% |####################           | ETA:  0:00:00   1.62 MB/s
# jupyter_dashbo  66% |####################           | ETA:  0:00:00   1.66 MB/s
# jupyter_dashbo  68% |#####################          | ETA:  0:00:00   1.68 MB/s
# jupyter_dashbo  70% |#####################          | ETA:  0:00:00   1.70 MB/s
# jupyter_dashbo  72% |######################         | ETA:  0:00:00   1.74 MB/s
# jupyter_dashbo  73% |######################         | ETA:  0:00:00   1.77 MB/s
# jupyter_dashbo  75% |#######################        | ETA:  0:00:00   1.79 MB/s
# jupyter_dashbo  77% |#######################        | ETA:  0:00:00   1.81 MB/s
# jupyter_dashbo  78% |########################       | ETA:  0:00:00   1.84 MB/s
# jupyter_dashbo  80% |########################       | ETA:  0:00:00   1.87 MB/s
# jupyter_dashbo  82% |#########################      | ETA:  0:00:00   1.90 MB/s
# jupyter_dashbo  84% |##########################     | ETA:  0:00:00   1.92 MB/s
# jupyter_dashbo  85% |##########################     | ETA:  0:00:00   1.94 MB/s
# jupyter_dashbo  87% |###########################    | ETA:  0:00:00   1.97 MB/s
# jupyter_dashbo  89% |###########################    | ETA:  0:00:00   2.00 MB/s
# jupyter_dashbo  90% |############################   | ETA:  0:00:00   2.02 MB/s
# jupyter_dashbo  92% |############################   | ETA:  0:00:00   2.05 MB/s
# jupyter_dashbo  94% |#############################  | ETA:  0:00:00   2.08 MB/s
# jupyter_dashbo  96% |#############################  | ETA:  0:00:00   2.10 MB/s
# jupyter_dashbo  97% |############################## | ETA:  0:00:00   2.13 MB/s
# jupyter_dashbo  99% |############################## | ETA:  0:00:00   2.16 MB/s
# jupyter_dashbo 100% |###############################| Time: 0:00:00   2.17 MB/s
#
# Installing C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension -> jupyter_dashboards
# Making directory: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\
# Making directory: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\link-css.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\link-css.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\main.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\main.js
# Making directory: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components
# Making directory: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\gridstack
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\gridstack\.bower.json -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\gridstack\.bower.json
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\gridstack\bower.json -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\gridstack\bower.json
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\gridstack\Gruntfile.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\gridstack\Gruntfile.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\gridstack\LICENSE -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\gridstack\LICENSE
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\gridstack\package.json -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\gridstack\package.json
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\gridstack\README.md -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\gridstack\README.md
# Making directory: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\gridstack\demo
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\gridstack\demo\float.html -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\gridstack\demo\float.html
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\gridstack\demo\knockout.html -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\gridstack\demo\knockout.html
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\gridstack\demo\knockout2.html -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\gridstack\demo\knockout2.html
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\gridstack\demo\nested.html -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\gridstack\demo\nested.html
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\gridstack\demo\serialization.html -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\gridstack\demo\serialization.html
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\gridstack\demo\two.html -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\gridstack\demo\two.html
# Making directory: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\gridstack\dist
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\gridstack\dist\gridstack-extra.css -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\gridstack\dist\gridstack-extra.css
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\gridstack\dist\gridstack-extra.min.css -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\gridstack\dist\gridstack-extra.min.css
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\gridstack\dist\gridstack.css -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\gridstack\dist\gridstack.css
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\gridstack\dist\gridstack.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\gridstack\dist\gridstack.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\gridstack\dist\gridstack.min.css -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\gridstack\dist\gridstack.min.css
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\gridstack\dist\gridstack.min.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\gridstack\dist\gridstack.min.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\gridstack\dist\gridstack.min.map -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\gridstack\dist\gridstack.min.map
# Making directory: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\gridstack\src
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\gridstack\src\gridstack-extra.scss -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\gridstack\src\gridstack-extra.scss
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\gridstack\src\gridstack.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\gridstack\src\gridstack.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\gridstack\src\gridstack.scss -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\gridstack\src\gridstack.scss
# Making directory: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\.bower.json -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\.bower.json
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\AUTHORS.txt -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\AUTHORS.txt
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\bower.json -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\bower.json
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\LICENSE.txt -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\LICENSE.txt
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\README.md -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\README.md
# Making directory: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\dist
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\dist\core.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\dist\core.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\dist\jquery.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\dist\jquery.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\dist\jquery.min.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\dist\jquery.min.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\dist\jquery.min.map -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\dist\jquery.min.map
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\dist\jquery.slim.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\dist\jquery.slim.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\dist\jquery.slim.min.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\dist\jquery.slim.min.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\dist\jquery.slim.min.map -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\dist\jquery.slim.min.map
# Making directory: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\external
# Making directory: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\external\sizzle
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\external\sizzle\LICENSE.txt -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\external\sizzle\LICENSE.txt
# Making directory: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\external\sizzle\dist
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\external\sizzle\dist\sizzle.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\external\sizzle\dist\sizzle.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\external\sizzle\dist\sizzle.min.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\external\sizzle\dist\sizzle.min.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\external\sizzle\dist\sizzle.min.map -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\external\sizzle\dist\sizzle.min.map
# Making directory: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\.eslintrc.json -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\.eslintrc.json
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\ajax.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\ajax.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\attributes.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\attributes.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\callbacks.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\callbacks.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\core.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\core.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\css.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\css.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\data.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\data.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\deferred.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\deferred.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\deprecated.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\deprecated.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\dimensions.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\dimensions.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\effects.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\effects.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\event.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\event.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\jquery.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\jquery.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\manipulation.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\manipulation.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\offset.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\offset.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\queue.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\queue.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\selector-native.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\selector-native.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\selector-sizzle.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\selector-sizzle.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\selector.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\selector.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\serialize.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\serialize.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\traversing.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\traversing.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\wrap.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\wrap.js
# Making directory: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\ajax
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\ajax\jsonp.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\ajax\jsonp.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\ajax\load.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\ajax\load.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\ajax\parseXML.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\ajax\parseXML.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\ajax\script.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\ajax\script.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\ajax\xhr.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\ajax\xhr.js
# Making directory: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\ajax\var
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\ajax\var\location.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\ajax\var\location.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\ajax\var\nonce.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\ajax\var\nonce.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\ajax\var\rquery.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\ajax\var\rquery.js
# Making directory: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\attributes
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\attributes\attr.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\attributes\attr.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\attributes\classes.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\attributes\classes.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\attributes\prop.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\attributes\prop.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\attributes\support.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\attributes\support.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\attributes\val.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\attributes\val.js
# Making directory: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\core
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\core\access.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\core\access.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\core\DOMEval.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\core\DOMEval.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\core\init.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\core\init.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\core\nodeName.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\core\nodeName.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\core\parseHTML.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\core\parseHTML.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\core\ready-no-deferred.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\core\ready-no-deferred.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\core\ready.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\core\ready.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\core\readyException.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\core\readyException.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\core\stripAndCollapse.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\core\stripAndCollapse.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\core\support.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\core\support.js
# Making directory: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\core\var
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\core\var\rsingleTag.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\core\var\rsingleTag.js
# Making directory: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\css
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\css\addGetHookIf.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\css\addGetHookIf.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\css\adjustCSS.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\css\adjustCSS.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\css\curCSS.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\css\curCSS.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\css\hiddenVisibleSelectors.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\css\hiddenVisibleSelectors.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\css\showHide.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\css\showHide.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\css\support.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\css\support.js
# Making directory: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\css\var
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\css\var\cssExpand.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\css\var\cssExpand.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\css\var\getStyles.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\css\var\getStyles.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\css\var\isHiddenWithinTree.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\css\var\isHiddenWithinTree.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\css\var\rmargin.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\css\var\rmargin.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\css\var\rnumnonpx.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\css\var\rnumnonpx.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\css\var\swap.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\css\var\swap.js
# Making directory: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\data
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\data\Data.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\data\Data.js
# Making directory: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\data\var
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\data\var\acceptData.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\data\var\acceptData.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\data\var\dataPriv.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\data\var\dataPriv.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\data\var\dataUser.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\data\var\dataUser.js
# Making directory: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\deferred
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\deferred\exceptionHook.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\deferred\exceptionHook.js
# Making directory: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\effects
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\effects\animatedSelector.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\effects\animatedSelector.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\effects\Tween.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\effects\Tween.js
# Making directory: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\event
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\event\ajax.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\event\ajax.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\event\alias.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\event\alias.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\event\focusin.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\event\focusin.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\event\support.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\event\support.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\event\trigger.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\event\trigger.js
# Making directory: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\exports
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\exports\amd.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\exports\amd.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\jquery\src\exports\global.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\exports\global.js
# Making directory: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\jquery\src\manipulation
# ...
# Making directory: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\lodash\vendor\underscore\test
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\lodash\vendor\underscore\test\arrays.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\lodash\vendor\underscore\test\arrays.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\lodash\vendor\underscore\test\chaining.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\lodash\vendor\underscore\test\chaining.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\lodash\vendor\underscore\test\collections.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\lodash\vendor\underscore\test\collections.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\lodash\vendor\underscore\test\cross-document.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\lodash\vendor\underscore\test\cross-document.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\lodash\vendor\underscore\test\functions.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\lodash\vendor\underscore\test\functions.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\lodash\vendor\underscore\test\objects.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\lodash\vendor\underscore\test\objects.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\lodash\vendor\underscore\test\utility.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\lodash\vendor\underscore\test\utility.js
# Making directory: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\requirejs
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\requirejs\.bower.json -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\requirejs\.bower.json
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\requirejs\bower.json -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\requirejs\bower.json
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\requirejs\README.md -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\requirejs\README.md
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\requirejs\require.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\requirejs\require.js
# Making directory: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\requirejs-text
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\requirejs-text\.bower.json -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\requirejs-text\.bower.json
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\requirejs-text\bower.json -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\requirejs-text\bower.json
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\requirejs-text\LICENSE -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\requirejs-text\LICENSE
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\requirejs-text\package.json -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\requirejs-text\package.json
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\requirejs-text\README.md -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\requirejs-text\README.md
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\bower_components\requirejs-text\text.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\bower_components\requirejs-text\text.js
# Making directory: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\dashboard-common
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\dashboard-common\dashboard-common.css -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\dashboard-common\dashboard-common.css
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\dashboard-common\error-log.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\dashboard-common\error-log.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\dashboard-common\gridstack-custom.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\dashboard-common\gridstack-custom.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\dashboard-common\gridstack-overrides.css -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\dashboard-common\gridstack-overrides.css
# Making directory: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\dashboard-view
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\dashboard-view\dashboard-actions.css -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\dashboard-view\dashboard-actions.css
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\dashboard-view\dashboard-actions.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\dashboard-view\dashboard-actions.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\dashboard-view\dashboard-metadata-compatibility.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\dashboard-view\dashboard-metadata-compatibility.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\dashboard-view\dashboard-metadata.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\dashboard-view\dashboard-metadata.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\dashboard-view\dashboard-view.css -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\dashboard-view\dashboard-view.css
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\dashboard-view\dashboard-view.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\dashboard-view\dashboard-view.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\dashboard-view\help.html -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\dashboard-view\help.html
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\dashboard-view\notebook-util.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\dashboard-view\notebook-util.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\dashboard-view\object-util.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\dashboard-view\object-util.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\dashboard-view\polymer-support.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\dashboard-view\polymer-support.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\dashboard-view\sub-menu.html -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\dashboard-view\sub-menu.html
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\dashboard-view\template-loader.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\dashboard-view\template-loader.js
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\dashboard-view\view-menu.html -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\dashboard-view\view-menu.html
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\dashboard-view\view-toolbar-buttons.html -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\dashboard-view\view-toolbar-buttons.html
# Making directory: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\dashboard-view\layout
# Making directory: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\dashboard-view\layout\grid
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\dashboard-view\layout\grid\cell-controls.html -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\dashboard-view\layout\grid\cell-controls.html
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\dashboard-view\layout\grid\layout.css -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\dashboard-view\layout\grid\layout.css
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\dashboard-view\layout\grid\layout.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\dashboard-view\layout\grid\layout.js
# Making directory: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\dashboard-view\layout\report
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\dashboard-view\layout\report\cell-controls.html -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\dashboard-view\layout\report\cell-controls.html
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\dashboard-view\layout\report\collapse-button.html -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\dashboard-view\layout\report\collapse-button.html
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\dashboard-view\layout\report\layout.css -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\dashboard-view\layout\report\layout.css
# Copying: C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\lib\site-packages\jupyter_dashboards\nbextension\notebook\dashboard-view\layout\report\layout.js -> C:\Users\gun10635\AppData\Local\ESRI\conda\envs\palm-detection\share\jupyter\nbextensions\jupyter_dashboards\notebook\dashboard-view\layout\report\layout.js
# - Validating: ok
#
#     To initialize this nbextension in the browser every time the notebook (or other app) loads:
#
#           jupyter nbextension enable jupyter_dashboards --py --sys-prefix
#
# Enabling notebook extension jupyter_dashboards/notebook/main...
#       - Validating: ok
#
#
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# <img src="../../static/img/02_change_detection_app_01.gif">

# %% [markdown]
# ### Connect to ArcGIS Online

# %%
from arcgis.gis import GIS
from arcgis.geocoding import geocode
from arcgis.raster.functions import *
from arcgis import geometry
    
import pandas as pd

# connect as an anonymous user
gis = GIS()

# search for the landsat multispectral imagery layer
landsat_item = gis.content.search('Landsat Multispectral', 'Imagery Layer', outside_org=True)[0]
landsat = landsat_item.layers[0]
df = None
import ipywidgets as widgets

# text box widget
location = widgets.Text(value='Ranchi, India', placeholder='Ranchi, India',
                        description='Location:', disabled=False)

# command button widget
gobtn = widgets.Button(description='Go', disabled=False,
                       button_style='', tooltip='Go', icon='check')

# define what happens whent the command button is clicked
def on_gobutton_clicked(b):
    global df
    global m
    global oldslider
    
    # geocode the place name and set that as the map's extent
    area = geocode(location.value)[0]
    m.extent = area['extent']
    df = filter_images()
    
gobtn.on_click(on_gobutton_clicked)

location_items = [location, gobtn]
widgets.HBox(location_items)
oldindex =  0 # int(len(df)/2)

# before image date slider
oldslider = widgets.IntSlider(value=oldindex, min=0,max=10, #len(df) - 1,
                              step=1, description='Older:', disabled=False,
                              continuous_update=True, orientation='horizontal',
                              readout=False, readout_format='f', slider_color='white')

old_label = widgets.Label(value='')#str(df.Time.iloc[oldindex].date()))

# define the slider behavior
def on_old_value_change(change):
    global df
    i = change['new']
    if df is not None:
        try:
            # print(df.Time.iloc[i].date())
            old_label.value = str(df.Time.iloc[i].date())
        except:
            pass
        
oldslider.observe(on_old_value_change, names='value')    
widgets.HBox([oldslider, old_label])

newindex = 0 # len(df) - 1

# after image date slider
newslider = widgets.IntSlider(value=newindex, min=0, max=10, #len(df) - 1,
                              step=1, description='Newer:', disabled=False,
                              continuous_update=True, orientation='horizontal',
                              readout=False, readout_format='f', slider_color='white')

new_label = widgets.Label(value='') #str(df.Time.iloc[newindex].date()))

# define the slider behavior
def on_new_value_change(change):
    global df
    i = change['new']
    if df is not None:
        try:
        # print(df.Time.iloc[i].date())
            new_label.value = str(df.Time.iloc[i].date())
        except:
            pass
newslider.observe(on_new_value_change, names='value')
widgets.HBox([newslider, new_label])

def update_sliders(tdf):
    global oldslider
    global newslider
    
    oldslider.max = len(tdf) - 1
    newslider.max = len(tdf) -1
    oldindex = int(len(tdf)/2)
    newindex = int(len(tdf) -1)
    oldslider.value = oldindex
    newslider.value = newindex
    old_label.value = str(tdf.Time.iloc[oldindex].date())
    new_label.value = str(tdf.Time.iloc[newindex].date())


def filter_images():
    global df
    area = geocode(location.value, out_sr=landsat.properties.spatialReference)[0]
    extent = area['extent']

    selected = landsat.filter_by(where="(Category = 1) AND (CloudCover <=0.10)", 
                             geometry=geometry.filters.intersects(extent))
    fs = selected.query(out_fields="AcquisitionDate, GroupName, Best, CloudCover, WRS_Row, WRS_Path, Month, Name", 
                  return_geometry=True,
                  return_distinct_values=False,
                  order_by_fields="AcquisitionDate")
    tdf = fs.sdf
    df = tdf
    tdf['Time'] = pd.to_datetime(tdf['AcquisitionDate'], unit='ms')    
    
    if len(tdf) > 1:
        update_sliders(tdf)

    # m.draw(tdf.iloc[oldslider.value].SHAPE)
    
    return tdf

df = filter_images()

# create the action button
diffbtn = widgets.Button(description='Detect changes', disabled=False,
                         button_style='success', tooltip='Show Different Image',
                         icon='check')

def on_diffbutton_clicked(b):
    # m.clear_graphics()
    first = df.iloc[oldslider.value].OBJECTID
    last = df.iloc[newslider.value].OBJECTID
    old = landsat.filter_by('OBJECTID='+str(first))
    new = landsat.filter_by('OBJECTID='+str(last))
    diff = stretch(composite_band([ndvi(old, '5 4'),
                               ndvi(new, '5 4'),
                               ndvi(old, '5 4')]), 
                               stretch_type='stddev',  num_stddev=3, min=0, max=255, dra=True, astype='u8')
    m.add_layer(diff)
    
diffbtn.on_click(on_diffbutton_clicked)
diffbtn

m = gis.map(location.value)
m.add_layer(landsat)
display(m)
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-15ba1e5c-4566-498b-a2ed-c6ea5cb2bda5"><img src=""></img></div>

# %% [markdown]
# ### Create widget controls to accept place of interest
# We use the `widgets` module from `ipywidgets` to create a text box and command button controls. These controls allow the user to specify a place of interest.

# %%
# Out:
# HBox(children=(Text(value='Ranchi, India', description='Location:', placeholder='Ranchi, India'), Button(descr…

# %% [markdown]
# Create the map widget and load the landsat imagery layer

# %%
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-e9830079-80a9-402c-81cb-56c041eab490"><img src=""></img></div>

# %% [markdown]
# ### Create date slider controls
# We create two slider controls to pick the before and after dates.

# %%
# Out:
# HBox(children=(IntSlider(value=0, description='Older:', max=10, readout=False, readout_format='f'), Label(valu…

# %%
# Out:
# HBox(children=(IntSlider(value=0, description='Newer:', max=10, readout=False, readout_format='f'), Label(valu…

# %% [markdown]
# ### Query the time enabled landast imagery layer
# Based on the dates selected from the sliders, we filter the layer for images

# %% [markdown]
# ### Perform change detection when the action button is clicked
# We create a command button and when it is clicked, display the difference in NDVI values in shades of green and magenta.

# %%
# Out:
# Button(button_style='success', description='Detect changes', icon='check', style=ButtonStyle(), tooltip='Show …

# %% [markdown]
# <blockquote>To run this sample as a dashboard, first run all the cells. Then if you have the `jupyter dashboard` package installed, you should see a `Dashboard View` set of buttons in your cell toolbar. Click on the `Dashboard preview` button to run it.</blockquote>
#
# ### Conclusion
# This sample demonstrates how developers can make use of the Python API and the rich Jupyter ecosystem to quickly build web apps.
