# %% [markdown]
# # Identifying country names from incomplete house addresses with model explainability

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc">
# <ul class="toc-item">
# <li><span><a href="#Introduction" data-toc-modified-id="Introduction-1">Introduction</a></span></li>
# <li><span><a href="#Prerequisites" data-toc-modified-id="Prerequisites-2">Prerequisites</a></span></li>
# <li><span><a href="#Imports" data-toc-modified-id="Imports-3">Imports</a></span></li>
# <li><span><a href="#Data-preparation" data-toc-modified-id="Data-preparation-4">Data preparation</a></span></li>
# <li><span><a href="#TextClassifier-model" data-toc-modified-id="TextClassifier-model-5">TextClassifier model</a></span></li>
# <ul class="toc-item">
# <li><span><a href="#Load-model-architecture" data-toc-modified-id="Load-model-architecture-5.1">Load model architecture</a></span></li>
# <li><span><a href="#Model-training" data-toc-modified-id="Model-training-5.2">Model training</a></span></li>
# <li><span><a href="#Validate-results" data-toc-modified-id="Validate-results-5.3">Validate results</a></span></li>
# <li><span><a href="#Model-metrics" data-toc-modified-id="Model-metrics-5.4">Model metrics</a></span></li>
# <li><span><a href="#Get-misclassified-records" data-toc-modified-id="Get-misclassified-records-5.5">Get misclassified records</a></span></li>
# <li><span><a href="#Saving-the-trained-model" data-toc-modified-id="Saving-the-trained-model-5.6">Saving the trained model</a></span></li>
# </ul>
# <li><span><a href="#Model-inference" data-toc-modified-id="Model-inference-6">Model inference</a></span></li>
# <li><span><a href="#Conclusion" data-toc-modified-id="Conclusion-7">Conclusion</a></span></li>
# <li><span><a href="#References" data-toc-modified-id="References-8">References</a></span></li>
# </ul></div>

# %% [markdown]
# # Introduction

# %% [markdown]
# [Geocoding](https://en.wikipedia.org/wiki/Geocoding) is the process of taking input text, such as an **address** or the name of a place, and returning a **latitude/longitude** location for that place. In this notebook, we will be picking up a dataset consisting of incomplete house addresses from 10 countries. We will build a classifier using `TextClassifier` class of `arcgis.learn.text` module to predict the country for these incomplete house addresses.
#
# The house addresses in the dataset consist of text in multiple languages like English, Japanese, French, Spanish, etc. The dataset is a small subset of the house addresses taken from [OpenAddresses data](http://results.openaddresses.io/)
#
# **A note on the dataset**
# - The data is collected around 2020-05-27 by [OpenAddresses](http://openaddresses.io).
# - The data licenses can be found in `data/country-classifier/LICENSE.txt`.

# %% [markdown]
# # Prerequisites

# %% [markdown]
# - Data preparation and model training workflows using arcgis.learn have a dependency on [transformers](https://huggingface.co/transformers/v3.0.2/index.html). Refer to the section **"Install deep learning dependencies of arcgis.learn module"** [on this page](https://developers.arcgis.com/python/guide/install-and-set-up/#Install-deep-learning-dependencies) for detailed documentation on the installation of the dependencies.
#
# - **Labeled data**: For `TextClassifier` to learn, it needs to see documents/texts that have been assigned a label. Labeled data for this sample notebook is located at `data/country-classifier/house-addresses.csv`
#
# - To learn more about how `TextClassifier` works, please see the guide on [Text Classification with arcgis.learn](https://developers.arcgis.com/python/guide/text-classification).

# %% [markdown]
# # Imports

# %%
import arcpy
import os
from collections import Counter
import zipfile
import pandas as pd
from pathlib import Path
import transformers
from arcgis.gis import GIS
from arcgis.learn import prepare_textdata
from arcgis.learn.text import TextClassifier

# %%
gis = GIS("home")

# %%
transformers.__version__
# Out:
# '4.24.0'

# %% [markdown]
# # Data preparation
#
# Data preparation involves splitting the data into training and validation sets, creating the necessary data structures for loading data into the model and so on. The `prepare_data()` function can directly read the training samples and automate the entire process.

# %%
training_data = gis.content.get("ab36969cfe814c89ba3b659cf734492a")
training_data
# Out:
# <Item title:"country_classifier" type:Image Collection owner:api_data_owner>

# %%
filepath = training_data.download(file_name=training_data.name)
# filepath="C:\\Users\\kaj13232\\Documents\\Work\\NLP Notebook Samples\\country_classifier.zip"

# %%
with zipfile.ZipFile(filepath, "r") as zip_ref:
    zip_ref.extractall(Path(filepath).parent)

# %%
DATA_ROOT = Path(os.path.join(os.path.splitext(filepath)[0]))

# %%
data = prepare_textdata(
    DATA_ROOT,
    "classification",
    train_file="house-addresses.csv",
    text_columns="Address",
    label_columns="Country",
    batch_size=64,
)

# %% [markdown]
# The `show_batch()` method can be used to see the training samples, along with labels.

# %%
data.show_batch(10)
# Out:
# this method is deprecated in favour of `Styler.hide(axis='index')`
# <style type="text/css">
# #T_a5922 th {
#   text-align: left;
# }
# #T_a5922_row0_col0, #T_a5922_row0_col1, #T_a5922_row1_col0, #T_a5922_row1_col1, #T_a5922_row2_col0, #T_a5922_row2_col1, #T_a5922_row3_col0, #T_a5922_row3_col1, #T_a5922_row4_col0, #T_a5922_row4_col1, #T_a5922_row5_col0, #T_a5922_row5_col1, #T_a5922_row6_col0, #T_a5922_row6_col1, #T_a5922_row7_col0, #T_a5922_row7_col1, #T_a5922_row8_col0, #T_a5922_row8_col1, #T_a5922_row9_col0, #T_a5922_row9_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_a5922">
#   <thead>
#     <tr>
#       <th id="T_a5922_level0_col0" class="col_heading level0 col0" >source</th>
#       <th id="T_a5922_level0_col1" class="col_heading level0 col1" >target</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a5922_row0_col0" class="data row0 col0" >585-9, 貝山字佐藤六</td>
#       <td id="T_a5922_row0_col1" class="data row0 col1" >JP</td>
#     </tr>
#     <tr>
#       <td id="T_a5922_row1_col0" class="data row1 col0" >150, Elmora Avenue, ELIZABETH, 07202</td>
#       <td id="T_a5922_row1_col1" class="data row1 col1" >US</td>
#     </tr>
#     <tr>
#       <td id="T_a5922_row2_col0" class="data row2 col0" >42, CALLE AVENIDA NEVADO DE TOLUCA, CIUDAD LÓPEZ MATEOS, Atizapán de Zaragoza, México</td>
#       <td id="T_a5922_row2_col1" class="data row2 col1" >MX</td>
#     </tr>
#     <tr>
#       <td id="T_a5922_row3_col0" class="data row3 col0" >135, Chemin de Petit Jardin, Trois-Rivières, 97114</td>
#       <td id="T_a5922_row3_col1" class="data row3 col1" >FR</td>
#     </tr>
#     <tr>
#       <td id="T_a5922_row4_col0" class="data row4 col0" >35, CALLE PUERTO ACAPULCO, TLAQUEPAQUE, Tlaquepaque, Jalisco</td>
#       <td id="T_a5922_row4_col1" class="data row4 col1" >MX</td>
#     </tr>
#     <tr>
#       <td id="T_a5922_row5_col0" class="data row5 col0" >1731, CALLE MADRID, IRAPUATO, Irapuato, Guanajuato</td>
#       <td id="T_a5922_row5_col1" class="data row5 col1" >MX</td>
#     </tr>
#     <tr>
#       <td id="T_a5922_row6_col0" class="data row6 col0" >1ter, Chemin du Bois Dieu, Treteau, 03220</td>
#       <td id="T_a5922_row6_col1" class="data row6 col1" >FR</td>
#     </tr>
#     <tr>
#       <td id="T_a5922_row7_col0" class="data row7 col0" >26, PRIVADA DEL CONDE, HERÓICA PUEBLA DE ZARAGOZA, Puebla, Puebla</td>
#       <td id="T_a5922_row7_col1" class="data row7 col1" >MX</td>
#     </tr>
#     <tr>
#       <td id="T_a5922_row8_col0" class="data row8 col0" >The Big Five False Bay NU, New</td>
#       <td id="T_a5922_row8_col1" class="data row8 col1" >ZA</td>
#     </tr>
#     <tr>
#       <td id="T_a5922_row9_col0" class="data row9 col0" >4494, CALLE NUNO BELTRÁN DE GUZMÁN, CULIACÁN ROSALES, Culiacán, Sinaloa</td>
#       <td id="T_a5922_row9_col1" class="data row9 col1" >MX</td>
#     </tr>
#   </tbody>
# </table>

# %%
data.show_batch(100)
# Out:
# this method is deprecated in favour of `Styler.hide(axis='index')`
# <style type="text/css">
# #T_5d759 th {
#   text-align: left;
# }
# #T_5d759_row0_col0, #T_5d759_row0_col1, #T_5d759_row1_col0, #T_5d759_row1_col1, #T_5d759_row2_col0, #T_5d759_row2_col1, #T_5d759_row3_col0, #T_5d759_row3_col1, #T_5d759_row4_col0, #T_5d759_row4_col1, #T_5d759_row5_col0, #T_5d759_row5_col1, #T_5d759_row6_col0, #T_5d759_row6_col1, #T_5d759_row7_col0, #T_5d759_row7_col1, #T_5d759_row8_col0, #T_5d759_row8_col1, #T_5d759_row9_col0, #T_5d759_row9_col1, #T_5d759_row10_col0, #T_5d759_row10_col1, #T_5d759_row11_col0, #T_5d759_row11_col1, #T_5d759_row12_col0, #T_5d759_row12_col1, #T_5d759_row13_col0, #T_5d759_row13_col1, #T_5d759_row14_col0, #T_5d759_row14_col1, #T_5d759_row15_col0, #T_5d759_row15_col1, #T_5d759_row16_col0, #T_5d759_row16_col1, #T_5d759_row17_col0, #T_5d759_row17_col1, #T_5d759_row18_col0, #T_5d759_row18_col1, #T_5d759_row19_col0, #T_5d759_row19_col1, #T_5d759_row20_col0, #T_5d759_row20_col1, #T_5d759_row21_col0, #T_5d759_row21_col1, #T_5d759_row22_col0, #T_5d759_row22_col1, #T_5d759_row23_col0, #T_5d759_row23_col1, #T_5d759_row24_col0, #T_5d759_row24_col1, #T_5d759_row25_col0, #T_5d759_row25_col1, #T_5d759_row26_col0, #T_5d759_row26_col1, #T_5d759_row27_col0, #T_5d759_row27_col1, #T_5d759_row28_col0, #T_5d759_row28_col1, #T_5d759_row29_col0, #T_5d759_row29_col1, #T_5d759_row30_col0, #T_5d759_row30_col1, #T_5d759_row31_col0, #T_5d759_row31_col1, #T_5d759_row32_col0, #T_5d759_row32_col1, #T_5d759_row33_col0, #T_5d759_row33_col1, #T_5d759_row34_col0, #T_5d759_row34_col1, #T_5d759_row35_col0, #T_5d759_row35_col1, #T_5d759_row36_col0, #T_5d759_row36_col1, #T_5d759_row37_col0, #T_5d759_row37_col1, #T_5d759_row38_col0, #T_5d759_row38_col1, #T_5d759_row39_col0, #T_5d759_row39_col1, #T_5d759_row40_col0, #T_5d759_row40_col1, #T_5d759_row41_col0, #T_5d759_row41_col1, #T_5d759_row42_col0, #T_5d759_row42_col1, #T_5d759_row43_col0, #T_5d759_row43_col1, #T_5d759_row44_col0, #T_5d759_row44_col1, #T_5d759_row45_col0, #T_5d759_row45_col1, #T_5d759_row46_col0, #T_5d759_row46_col1, #T_5d759_row47_col0, #T_5d759_row47_col1, #T_5d759_row48_col0, #T_5d759_row48_col1, #T_5d759_row49_col0, #T_5d759_row49_col1, #T_5d759_row50_col0, #T_5d759_row50_col1, #T_5d759_row51_col0, #T_5d759_row51_col1, #T_5d759_row52_col0, #T_5d759_row52_col1, #T_5d759_row53_col0, #T_5d759_row53_col1, #T_5d759_row54_col0, #T_5d759_row54_col1, #T_5d759_row55_col0, #T_5d759_row55_col1, #T_5d759_row56_col0, #T_5d759_row56_col1, #T_5d759_row57_col0, #T_5d759_row57_col1, #T_5d759_row58_col0, #T_5d759_row58_col1, #T_5d759_row59_col0, #T_5d759_row59_col1, #T_5d759_row60_col0, #T_5d759_row60_col1, #T_5d759_row61_col0, #T_5d759_row61_col1, #T_5d759_row62_col0, #T_5d759_row62_col1, #T_5d759_row63_col0, #T_5d759_row63_col1, #T_5d759_row64_col0, #T_5d759_row64_col1, #T_5d759_row65_col0, #T_5d759_row65_col1, #T_5d759_row66_col0, #T_5d759_row66_col1, #T_5d759_row67_col0, #T_5d759_row67_col1, #T_5d759_row68_col0, #T_5d759_row68_col1, #T_5d759_row69_col0, #T_5d759_row69_col1, #T_5d759_row70_col0, #T_5d759_row70_col1, #T_5d759_row71_col0, #T_5d759_row71_col1, #T_5d759_row72_col0, #T_5d759_row72_col1, #T_5d759_row73_col0, #T_5d759_row73_col1, #T_5d759_row74_col0, #T_5d759_row74_col1, #T_5d759_row75_col0, #T_5d759_row75_col1, #T_5d759_row76_col0, #T_5d759_row76_col1, #T_5d759_row77_col0, #T_5d759_row77_col1, #T_5d759_row78_col0, #T_5d759_row78_col1, #T_5d759_row79_col0, #T_5d759_row79_col1, #T_5d759_row80_col0, #T_5d759_row80_col1, #T_5d759_row81_col0, #T_5d759_row81_col1, #T_5d759_row82_col0, #T_5d759_row82_col1, #T_5d759_row83_col0, #T_5d759_row83_col1, #T_5d759_row84_col0, #T_5d759_row84_col1, #T_5d759_row85_col0, #T_5d759_row85_col1, #T_5d759_row86_col0, #T_5d759_row86_col1, #T_5d759_row87_col0, #T_5d759_row87_col1, #T_5d759_row88_col0, #T_5d759_row88_col1, #T_5d759_row89_col0, #T_5d759_row89_col1, #T_5d759_row90_col0, #T_5d759_row90_col1, #T_5d759_row91_col0, #T_5d759_row91_col1, #T_5d759_row92_col0, #T_5d759_row92_col1, #T_5d759_row93_col0, #T_5d759_row93_col1, #T_5d759_row94_col0, #T_5d759_row94_col1, #T_5d759_row95_col0, #T_5d759_ ...
#   text-align: left;
# }
# </style>
# <table id="T_5d759">
#   <thead>
#     <tr>
#       <th id="T_5d759_level0_col0" class="col_heading level0 col0" >source</th>
#       <th id="T_5d759_level0_col1" class="col_heading level0 col1" >target</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5d759_row0_col0" class="data row0 col0" >37, CALLE PINO, TLAQUEPAQUE, Tlaquepaque, Jalisco</td>
#       <td id="T_5d759_row0_col1" class="data row0 col1" >MX</td>
#     </tr>
#     <tr>
#       <td id="T_5d759_row1_col0" class="data row1 col0" >1006, AVENIDA IGNACIO DE LA LLAVE, COATZACOALCOS, Coatzacoalcos, Veracruz de Ignacio de la Llave</td>
#       <td id="T_5d759_row1_col1" class="data row1 col1" >MX</td>
#     </tr>
#     <tr>
#       <td id="T_5d759_row2_col0" class="data row2 col0" >258, Chemin de Serre Merlas, Balazuc, 07120</td>
#       <td id="T_5d759_row2_col1" class="data row2 col1" >FR</td>
#     </tr>
#     <tr>
#       <td id="T_5d759_row3_col0" class="data row3 col0" >15, RUA  DEZESSEIS, Rio de Janeiro, RJ, 21863-425</td>
#       <td id="T_5d759_row3_col1" class="data row3 col1" >BR</td>
#     </tr>
#     <tr>
#       <td id="T_5d759_row4_col0" class="data row4 col0" >30181, Ga-Ramoshwane, Polokwane</td>
#       <td id="T_5d759_row4_col1" class="data row4 col1" >ZA</td>
#     </tr>
#     <tr>
#       <td id="T_5d759_row5_col0" class="data row5 col0" >3064-9, 板橋</td>
#       <td id="T_5d759_row5_col1" class="data row5 col1" >JP</td>
#     </tr>
#     <tr>
#       <td id="T_5d759_row6_col0" class="data row6 col0" >8-7, 上野寿町</td>
#       <td id="T_5d759_row6_col1" class="data row6 col1" >JP</td>
#     </tr>
#     <tr>
#       <td id="T_5d759_row7_col0" class="data row7 col0" >2114, Evans Street, RAHWAY, 07065</td>
#       <td id="T_5d759_row7_col1" class="data row7 col1" >US</td>
#     </tr>
#     <tr>
#       <td id="T_5d759_row8_col0" class="data row8 col0" >SN, CALLE PASEO DE LOS JABALÍES, SALTILLO, Saltillo, Coahuila de Zaragoza</td>
#       <td id="T_5d759_row8_col1" class="data row8 col1" >MX</td>
#     </tr>
#     <tr>
#       <td id="T_5d759_row9_col0" class="data row9 col0" >2, SEVENS AVENUE, UNIT 2, EUROA, VIC, 3666</td>
#       <td id="T_5d759_row9_col1" class="data row9 col1" >AU</td>
#     </tr>
#     <tr>
#       <td id="T_5d759_row10_col0" class="data row10 col0" >54, PASSAGE RD, WATT SECTION, B0J 3B0</td>
#       <td id="T_5d759_row10_col1" class="data row10 col1" >CA</td>
#     </tr>
#     <tr>
#       <td id="T_5d759_row11_col0" class="data row11 col0" >36, Kamelialaan, Sint-Pieters-Woluwe, 1150</td>
#       <td id="T_5d759_row11_col1" class="data row11 col1" >BE</td>
#     </tr>
#     <tr>
#       <td id="T_5d759_row12_col0" class="data row12 col0" >597, RUA  ADOLFO SORMANI, Jaú, SP, 17210-544</td>
#       <td id="T_5d759_row12_col1" class="data row12 col1" >BR</td>
#     </tr>
#     <tr>
#       <td id="T_5d759_row13_col0" class="data row13 col0" >32, CALLE MZA 1 LT 3, TEPOTZOTLÁN, Tepotzotlán, México</td>
#       <td id="T_5d759_row13_col1" class="data row13 col1" >MX</td>
#     </tr>
#     <tr>
#       <td id="T_5d759_row14_col0" class="data row14 col0" >2F, CL ISLAS ALMIRANTE, 28039</td>
#       <td id="T_5d759_row14_col1" class="data row14 col1" >ES</td>
#     </tr>
#     <tr>
#       <td id="T_5d759_row15_col0" class="data row15 col0" >aMahlongwa, Umdoni</td>
#       <td id="T_5d759_row15_col1" class="data row15 col1" >ZA</td>
#     </tr>
#     <tr>
#       <td id="T_5d759_row16_col0" class="data row16 col0" >19, Seventh Avenue, Clermont, eThekwini</td>
#       <td id="T_5d759_row16_col1" class="data row16 col1" >ZA</td>
#     </tr>
#     <tr>
#       <td id="T_5d759_row17_col0" class="data row17 col0" >12, MANGROVE ROAD, AINTREE, VIC, 3336</td>
#       <td id="T_5d759_row17_col1" class="data row17 col1" >AU</td>
#     </tr>
#     <tr>
#       <td id="T_5d759_row18_col0" class="data row18 col0" >60, RUA  DO SOSS

# %% [markdown]
# # TextClassifier model

# %% [markdown]
# `TextClassifier` model in `arcgis.learn.text` is built on top of [Hugging Face Transformers](https://huggingface.co/transformers/v3.0.2/index.html) library. The model training and inferencing workflow are similar to computer vision models in `arcgis.learn`.
#
# Run the command below to see what backbones are supported for the text classification task.

# %%
print(TextClassifier.supported_backbones)
# Out:
# ['BERT', 'RoBERTa', 'DistilBERT', 'ALBERT', 'FlauBERT', 'CamemBERT', 'XLNet', 'XLM', 'XLM-RoBERTa', 'Bart', 'ELECTRA', 'Longformer', 'MobileBERT', 'Funnel']

# %% [markdown]
# Call the model's `available_backbone_models()` method with the backbone name to get the available models for that backbone. The call to **available_backbone_models** method will list out only few of the available models for each backbone. Visit [this](https://huggingface.co/transformers/pretrained_models.html) link to get a complete list of models for each backbone.

# %%
print(TextClassifier.available_backbone_models("xlm-roberta"))
# Out:
# ('xlm-roberta-base', 'xlm-roberta-large')

# %% [markdown]
# ## Load model architecture

# %% [markdown]
# Invoke the `TextClassifier` class by passing the data and the backbone you have chosen. The dataset consists of house addresses in multiple languages like Japanese, English, French, Spanish, etc., hence we will use a [multi-lingual transformer backbone](https://huggingface.co/transformers/v3.0.2/multilingual.html) to train our model.

# %%
model = TextClassifier(data, backbone="xlm-roberta-base")
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/615 [00:00<?, ?B/s]
# `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\kaj13232\.cache\huggingface\hub. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
# Downloading (…)tencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/9.10M [00:00<?, ?B/s]
# Downloading (…)"pytorch_model.bin";:   0%|          | 0.00/1.12G [00:00<?, ?B/s]

# %%
# model.load("country-classifier")

# %% [markdown]
# ## Model training

# %% [markdown]
# The `learning rate`[[1]](#References) is a **tuning parameter** that determines the step size at each iteration while moving toward a minimum of a loss function, it represents the speed at which a machine learning model **"learns"**. `arcgis.learn` includes a learning rate finder, and is accessible through the model's `lr_find()` method, that can automatically select an **optimum learning rate**, without requiring repeated experiments.

# %%
model.lr_find()
# Out:
# 0.00013182567385564074

# %% [markdown]
# Training the model is an iterative process. We can train the model using its `fit()` method till the validation loss (or error rate) continues to go down with each training pass also known as an epoch. This is indicative of the model learning the task.

# %%
model.fit(epochs=6, lr=0.00013182567385564074)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.091671</td>
#       <td>0.085025</td>
#       <td>0.975995</td>
#       <td>0.024005</td>
#       <td>03:17</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.107969</td>
#       <td>0.074215</td>
#       <td>0.976895</td>
#       <td>0.023105</td>
#       <td>03:18</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.067874</td>
#       <td>0.039669</td>
#       <td>0.985197</td>
#       <td>0.014803</td>
#       <td>03:10</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.039026</td>
#       <td>0.034880</td>
#       <td>0.986797</td>
#       <td>0.013203</td>
#       <td>03:15</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.026721</td>
#       <td>0.026260</td>
#       <td>0.988798</td>
#       <td>0.011202</td>
#       <td>03:13</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.012680</td>
#       <td>0.023542</td>
#       <td>0.989998</td>
#       <td>0.010002</td>
#       <td>03:11</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Validate results

# %% [markdown]
# Once we have the trained model, we can see the results to see how it performs.

# %%
model.show_results(15)
# Out:
# this method is deprecated in favour of `Styler.hide(axis='index')`
# <style type="text/css">
# #T_97170 th {
#   text-align: left;
# }
# #T_97170_row0_col0, #T_97170_row0_col1, #T_97170_row0_col2, #T_97170_row1_col0, #T_97170_row1_col1, #T_97170_row1_col2, #T_97170_row2_col0, #T_97170_row2_col1, #T_97170_row2_col2, #T_97170_row3_col0, #T_97170_row3_col1, #T_97170_row3_col2, #T_97170_row4_col0, #T_97170_row4_col1, #T_97170_row4_col2, #T_97170_row5_col0, #T_97170_row5_col1, #T_97170_row5_col2, #T_97170_row6_col0, #T_97170_row6_col1, #T_97170_row6_col2, #T_97170_row7_col0, #T_97170_row7_col1, #T_97170_row7_col2, #T_97170_row8_col0, #T_97170_row8_col1, #T_97170_row8_col2, #T_97170_row9_col0, #T_97170_row9_col1, #T_97170_row9_col2, #T_97170_row10_col0, #T_97170_row10_col1, #T_97170_row10_col2, #T_97170_row11_col0, #T_97170_row11_col1, #T_97170_row11_col2, #T_97170_row12_col0, #T_97170_row12_col1, #T_97170_row12_col2, #T_97170_row13_col0, #T_97170_row13_col1, #T_97170_row13_col2, #T_97170_row14_col0, #T_97170_row14_col1, #T_97170_row14_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_97170">
#   <thead>
#     <tr>
#       <th id="T_97170_level0_col0" class="col_heading level0 col0" >text</th>
#       <th id="T_97170_level0_col1" class="col_heading level0 col1" >target</th>
#       <th id="T_97170_level0_col2" class="col_heading level0 col2" >prediction</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_97170_row0_col0" class="data row0 col0" >1213, RUA BENJAMIN CONSTANT, ANDAR 02 APARTAMENTO 206 APARTAMENTO 205 APARTAMENTO 204 APARTAMENTO 203 APARTAMENTO 202, Blumenau, SC, 89035-100</td>
#       <td id="T_97170_row0_col1" class="data row0 col1" >BR</td>
#       <td id="T_97170_row0_col2" class="data row0 col2" >BR</td>
#     </tr>
#     <tr>
#       <td id="T_97170_row1_col0" class="data row1 col0" >3A, AVENIDA QUINTA SUR ORIENTE (PROF. DOMITILA AGUERA), COMITÁN DE DOMÍNGUEZ, Comitán de Domínguez, Chiapas</td>
#       <td id="T_97170_row1_col1" class="data row1 col1" >MX</td>
#       <td id="T_97170_row1_col2" class="data row1 col2" >MX</td>
#     </tr>
#     <tr>
#       <td id="T_97170_row2_col0" class="data row2 col0" >SN, RUA H CENTO E QUARENTA E CINCO, QUADRA 309 LOTE 16 CASA 2, Aparecida de Goiânia, GO, 74937-440</td>
#       <td id="T_97170_row2_col1" class="data row2 col1" >BR</td>
#       <td id="T_97170_row2_col2" class="data row2 col2" >BR</td>
#     </tr>
#     <tr>
#       <td id="T_97170_row3_col0" class="data row3 col0" >104, CALLE BAJA CALIFORNIA, FRACCIONAMIENTO VALLE HUEJÚCAR (FRACCIONAMIENTO POPULAR), Calvillo, Aguascalientes</td>
#       <td id="T_97170_row3_col1" class="data row3 col1" >MX</td>
#       <td id="T_97170_row3_col2" class="data row3 col2" >MX</td>
#     </tr>
#     <tr>
#       <td id="T_97170_row4_col0" class="data row4 col0" >1503, BOULEVARD LOS OLMECAS, FRACCIONAMIENTO CIUDAD OLMECA, Coatzacoalcos, Veracruz de Ignacio de la Llave</td>
#       <td id="T_97170_row4_col1" class="data row4 col1" >MX</td>
#       <td id="T_97170_row4_col2" class="data row4 col2" >MX</td>
#     </tr>
#     <tr>
#       <td id="T_97170_row5_col0" class="data row5 col0" >SN, AVENIDA HÉROE DE NOCUPÉTARO ORIENTE, NOCUPÉTARO DE MORELOS, Nocupétaro, Michoacán de Ocampo</td>
#       <td id="T_97170_row5_col1" class="data row5 col1" >MX</td>
#       <td id="T_97170_row5_col2" class="data row5 col2" >MX</td>
#     </tr>
#     <tr>
#       <td id="T_97170_row6_col0" class="data row6 col0" >SN, PRIVADA ALDAMA, DOLORES HIDALGO CUNA DE LA INDEPENDENCIA NACIONAL, Dolores Hidalgo Cuna de la Independencia Nacional, Guanajuato</td>
#       <td id="T_97170_row6_col1" class="data row6 col1" >MX</td>
#       <td id="T_97170_row6_col2" class="data row6 col2" >MX</td>
#     </tr>
#     <tr>
#       <td id="T_97170_row7_col0" class="data row7 col0" >65, RUA ANA PATRICIA COELHO DE BITTENCOURT, BLOCO C APARTAMENTO 201, Criciúma, SC, 88811-216</td>
#       <td id="T_97170_row7_col1" class="data row7 col1" >BR</td>
#       <td id="T_97170_row7_col2" class="data row7 col2" >BR</td>
#     </tr>
#     <tr>
#       <td id="T_97170_row8_col0" class="data row8 col0" >34, CALLE MELCHOR OCAMPO, COLONIA LÁZARO CÁRDENAS (1RA. SECCIÓN DEL RODEO), San Juan del Río, Querétaro</td>
#       <td id="T_97170_row8_col1" class="data row8 col1" >MX</td>
#       <td id="T_97170_row8_col2" class="data row8 col2" >MX</td>
#     </tr>
#     <tr>
#       <td id="T_97170_row9_col0" class="data row9 col0" >SN, RUA HUMBERTO BANDEIRA DE MELO, BLOCO 14 ENTRADA 1 APARTAMENTO 201, Rio de Janeiro, RJ, 21832-020</td>
#       <td id="T_97170_row9_col1" class="data row9 col1" >BR</td>
#       <td id="T_97170_row9_col2" class="data row9 col2" >BR</td>
#     </tr>
#     <tr>
#       <td id="T_97170_row10_col0" class="data row10 col0" >33, CALLE PUEBLA, DOLORES HIDALGO CUNA DE LA INDEPENDENCIA NACIONAL, Dolores Hidalgo Cuna de la Independencia Nacional, Guanajuato</td>
#       <td id="T_97170_row10_col1" class="data row10 col1" >MX</td>
#       <td id="T_97170_row10_col2" class="data row10 col2" >MX</td>
#     </tr>
#     <tr>
#       <td id="T_97170_row11_col0" class="data row11 col0" >SN, CALLE LÁZARO CANO PERÉZ, SOLEDAD DE GRACIANO SÁNCHEZ, Soledad de Graciano Sánchez, San Luis Potosí</td>
#       <td id="T_97170_row11_col1" class="data row11 col1" >MX</td>
#       <td id="T_97170_row11_col2" class="data row11 col2" >MX</td>
#     </tr>
#     <tr>
#       <td id="T_97170_row12_col0" class="data row12 col0" >1169, RUA DOUTOR ALBUQUERQUE LINS, BLOCO B ANDAR 11 APARTAMENTO 112B, São Paulo, SP, 01203-001</td>
#       <td id="T_97170_row12_col1" class="data row12 col1" >BR</td>
#       <td id="T_97170_row12_col2" class="data row12 col2" >BR</td>
#     </tr>
#     <tr>
#       <td id="T_97170_row13_col0" class="data row13 col0" >1126, CALLE MIGUEL LERDO DE TEJADA, JÁLTIPAN DE MORELOS, Jáltipan, Veracruz de Ignacio de la Llave</td>
#       <td id="T_97170_row13_col1" class="data row13 col1" >MX</td>
#       <td id="T_97170_row13_col2" class="data row13 col2" >MX</td>
#     </tr>
#     <tr>
#       <td id="T_97170_row14_col0" class="data row14 col0" >6, EJE VIAL 5 NORTE (AVENIDA RÍO GUADALUPE), GUSTAVO A. MADERO, Gustavo A. Madero, Distrito Federal</td>
#       <td id="T_97170_row14_col1" class="data row14 col1" >MX</td>
#       <td id="T_97170_row14_col2" class="data row14 col2" >MX</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Test the model prediction on an input text

# %%
text = """1016, 8A, CL RICARDO LEON - SANTA ANA (CARTAGENA), 30319"""
print(model.predict(text))
# Out:
# ('1016, 8A, CL RICARDO LEON - SANTA ANA (CARTAGENA), 30319', 'MX', 0.10092790424823761)

# %% [markdown]
# ## Model Explainability using SHAP

# %% [markdown]
# To understand how the model works and individual token contribution, we use Shapley Additive Explanations (SHAP) on the model.
#
# [Shapley Additive Explanations (SHAP)](https://github.com/slundberg/shap) values is a method for explaining the predictions of machine learning models. In the context of NLP, SHAP values can be used to understand how input features (or words in our case) influences the prediction of a model for a specific instance.
#
# To get explanations of **single instances** - we pass a single address to the `predict()` function the parameter `explain` set to True

# %%
text = """1016, 8A, CL RICARDO LEON - SANTA ANA (CARTAGENA), 30319"""
print(model.predict(text, explain=True))
# Out:
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[0]</div>
# </div>
#             <div align='center'>
# <script>
#     document._hover_nzwasrngqcllywgnexwh = '_tp_nzwasrngqcllywgnexwh_output_0';
#     document._zoom_nzwasrngqcllywgnexwh = undefined;
#     function _output_onclick_nzwasrngqcllywgnexwh(i) {
#         var next_id = undefined;
#
#         if (document._zoom_nzwasrngqcllywgnexwh !== undefined) {
#             document.getElementById(document._zoom_nzwasrngqcllywgnexwh+ '_zoom').style.display = 'none';
#
#             if (document._zoom_nzwasrngqcllywgnexwh === '_tp_nzwasrngqcllywgnexwh_output_' + i) {
#                 document.getElementById(document._zoom_nzwasrngqcllywgnexwh).style.display = 'block';
#                 document.getElementById(document._zoom_nzwasrngqcllywgnexwh+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_nzwasrngqcllywgnexwh).style.display = 'none';
#                 document.getElementById(document._zoom_nzwasrngqcllywgnexwh+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_nzwasrngqcllywgnexwh !== '_tp_nzwasrngqcllywgnexwh_output_' + i) {
#             next_id = '_tp_nzwasrngqcllywgnexwh_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_nzwasrngqcllywgnexwh = next_id;
#     }
#     function _output_onmouseover_nzwasrngqcllywgnexwh(i, el) {
#         if (document._zoom_nzwasrngqcllywgnexwh !== undefined) { return; }
#         if (document._hover_nzwasrngqcllywgnexwh !== undefined) {
#             document.getElementById(document._hover_nzwasrngqcllywgnexwh + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_nzwasrngqcllywgnexwh).style.display = 'none';
#         }
#         document.getElementById('_tp_nzwasrngqcllywgnexwh_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_nzwasrngqcllywgnexwh = '_tp_nzwasrngqcllywgnexwh_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius: 3px; padding: 0px" id="_tp_nzwasrngqcllywgnexwh_output_0_name"
#     onclick="_output_onclick_nzwasrngqcllywgnexwh(0)"
#     onmouseover="_output_onmouseover_nzwasrngqcllywgnexwh(0, this);">AU</div>
# <div style="display: inline; border-bottom: none; background: rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius: 3px; padding: 0px" id="_tp_nzwasrngqcllywgnexwh_output_1_name"
#     onclick="_output_onclick_nzwasrngqcllywgnexwh(1)"
#     onmouseover="_output_onmouseover_nzwasrngqcllywgnexwh(1, this);">BE</div>
# <div style="display: inline; border-bottom: none; background: rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius: 3px; padding: 0px" id="_tp_nzwasrngqcllywgnexwh_output_2_name"
#     onclick="_output_onclick_nzwasrngqcllywgnexwh(2)"
#     onmouseover="_output_onmouseover_nzwasrngqcllywgnexwh(2, this);">BR</div>
# <div style="display: inline; border-bottom: none; background: rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius: 3px; padding: 0px" id="_tp_nzwasrngqcllywgnexwh_output_3_name"
#     onclick="_output_onclick_nzwasrngqcllywgnexwh(3)"
#     onmouseover="_output_onmouseover_nzwasrngqcllywgnexwh(3, this);">CA</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_nzwasrngqcllywgnexwh_output_4_name"
#     onclick="_output_onclick_nzwasrngqcllywgnexwh(4)"
#     onmouseover="_output_onmouseover_nzwasrngqcllywgnexwh(4, this);">ES</div>
# <div style="display: inline; border-bottom: none; background: rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius: 3px; padding: 0px" id="_tp_nzwasrngqcllywgnexwh_output_5_name"
#     onclick="_output_onclick_nzwasrngqcllywgnexwh(5)"
#     onmouseover="_output_onmouseover_nzwasrngqcllywgnexwh(5, this);">FR</div>
# <div style="display: inline; border-bottom: none; background: rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius: 3px; padding: 0px" id="_tp_nzwasrngqcllywgnexwh_output_6_name"
#     onclick="_output_onclick_nzwasrngqcllywgnexwh(6)"
#     onmouseover="_output_onmouseover_nzwasrngqcllywgnexwh(6, this);">JP</div>
# <div style="display: inline; border-bottom: none; background: rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius: 3px; padding: 0px" id="_tp_nzwasrngqcllywgnexwh_output_7_name"
#     onclick="_output_onclick_nzwasrngqcllywgnexwh(7)"
#     onmouseover="_output_onmouseover_nzwasrngqcllywgnexwh(7, this);">MX</div>
# <div style="display: inline; border-bottom: none; background: rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius: 3px; padding: 0px" id="_tp_nzwasrngqcllywgnexwh_output_8_name"
#     onclick="_output_onclick_nzwasrngqcllywgnexwh(8)"
#     onmouseover="_output_onmouseover_nzwasrngqcllywgnexwh(8, this);">US</div>
# <div style="display: inline; border-bottom: none; background: rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius: 3px; padding: 0px" id="_tp_nzwasrngqcllywgnexwh_output_9_name"
#     onclick="_output_onclick_nzwasrngqcllywgnexwh(9)"
#     onmouseover="_output_onmouseover_nzwasrngqcllywgnexwh(9, this);">ZA</div><br><br><div id='_tp_nzwasrngqcllywgnexwh_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="49.8709523896574%" y1="33" x2="49.8709523896574%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="49.8709523896574%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.4</text><line x1="38.00897732178249%" y1="33" x2="38.00897732178249%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="38.00897732178249%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.2</text><line x1="26.147002253907583%" y1="33" x2="26.147002253907583%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="26.147002253907583%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0</text><line x1="14.28502718603267%" y1="33" x2="14.28502718603267%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="14.28502718603267%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-0.2</text><line x1="61.73292745753231%" y1="33" x2="61.73292745753231%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="61.73292745753231%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.6</text><line x1="73.59490252540722%" y1="33" x2="73.59490252540722%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="73.59490252540722%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.8</text><line x1="85.45687759328213%" y1="33" x2="85.45687759328213%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="85.45687759328213%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">1</text><line x1="26.14710705445481%" y1="33" x2="26.14710705445481%" y2="37"
# ('1016, 8A, CL RICARDO LEON - SANTA ANA (CARTAGENA), 30319', 'ES', 0.9999511241912842)

# %% [markdown]
# In the plot above, when we hover the mouse over an output class, we get the explanation for that output class. When we click an output class name then that class remains the focus of the explanation visualization until we click another class.
#
# The base value is what the model outputs when the entire input text is masked (set to a constant or null), while $f_{output class}(inputs)$ is the output of the model for the full original input. The SHAP values explain in an addive way how the impact of unmasking each word changes the model output from the base value (where the entire input is masked) to the final prediction value.
#
# The features that were important to making the prediction for this observation are shown in red and blue, with red representing features that pushed the model score higher, and blue representing features that pushed the score lower. Features that had more of an impact on the score are located closer to the dividing boundary between red and blue, and the size of that impact is represented by the size of the bar.

# %% [markdown]
#
# To get explanations of **multiple instances** - we pass a list of addresses to the `predict()` function the parameter `explain` set to True and the parameter `explain_index` set as the list of indices we want to explain.

# %%
text = [
    """22, BULKARA ROAD, BELLEVUE HILL, NSW, 2023""",
    """30, RUA BOM MILAGRE, São Luís, MA, 65000-000""",
    """193, STAFFORD DRIVE, Wheeling, 60090""",
    """2375-3, 周東町上久原""",
    """35, CL CANCHUELA, 5400""",
]
print(model.predict(text, explain=True, explain_index=[1, 3]))
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='5' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [5/5 00:00<00:00]
#     </div>
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[0]</div>
# </div>
#             <div align='center'>
# <script>
#     document._hover_nzwasrngqcllywgnexwh = '_tp_nzwasrngqcllywgnexwh_output_0';
#     document._zoom_nzwasrngqcllywgnexwh = undefined;
#     function _output_onclick_nzwasrngqcllywgnexwh(i) {
#         var next_id = undefined;
#
#         if (document._zoom_nzwasrngqcllywgnexwh !== undefined) {
#             document.getElementById(document._zoom_nzwasrngqcllywgnexwh+ '_zoom').style.display = 'none';
#
#             if (document._zoom_nzwasrngqcllywgnexwh === '_tp_nzwasrngqcllywgnexwh_output_' + i) {
#                 document.getElementById(document._zoom_nzwasrngqcllywgnexwh).style.display = 'block';
#                 document.getElementById(document._zoom_nzwasrngqcllywgnexwh+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_nzwasrngqcllywgnexwh).style.display = 'none';
#                 document.getElementById(document._zoom_nzwasrngqcllywgnexwh+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_nzwasrngqcllywgnexwh !== '_tp_nzwasrngqcllywgnexwh_output_' + i) {
#             next_id = '_tp_nzwasrngqcllywgnexwh_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_nzwasrngqcllywgnexwh = next_id;
#     }
#     function _output_onmouseover_nzwasrngqcllywgnexwh(i, el) {
#         if (document._zoom_nzwasrngqcllywgnexwh !== undefined) { return; }
#         if (document._hover_nzwasrngqcllywgnexwh !== undefined) {
#             document.getElementById(document._hover_nzwasrngqcllywgnexwh + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_nzwasrngqcllywgnexwh).style.display = 'none';
#         }
#         document.getElementById('_tp_nzwasrngqcllywgnexwh_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_nzwasrngqcllywgnexwh = '_tp_nzwasrngqcllywgnexwh_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_nzwasrngqcllywgnexwh_output_0_name"
#     onclick="_output_onclick_nzwasrngqcllywgnexwh(0)"
#     onmouseover="_output_onmouseover_nzwasrngqcllywgnexwh(0, this);">AU</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 0.9921172509407804); border-radius: 3px; padding: 0px" id="_tp_nzwasrngqcllywgnexwh_output_1_name"
#     onclick="_output_onclick_nzwasrngqcllywgnexwh(1)"
#     onmouseover="_output_onmouseover_nzwasrngqcllywgnexwh(1, this);">BE</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_nzwasrngqcllywgnexwh_output_2_name"
#     onclick="_output_onclick_nzwasrngqcllywgnexwh(2)"
#     onmouseover="_output_onmouseover_nzwasrngqcllywgnexwh(2, this);">BR</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 0.9921172509407804); border-radius: 3px; padding: 0px" id="_tp_nzwasrngqcllywgnexwh_output_3_name"
#     onclick="_output_onclick_nzwasrngqcllywgnexwh(3)"
#     onmouseover="_output_onmouseover_nzwasrngqcllywgnexwh(3, this);">CA</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 0.9842345018815607); border-radius: 3px; padding: 0px" id="_tp_nzwasrngqcllywgnexwh_output_4_name"
#     onclick="_output_onclick_nzwasrngqcllywgnexwh(4)"
#     onmouseover="_output_onmouseover_nzwasrngqcllywgnexwh(4, this);">ES</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 0.9842345018815607); border-radius: 3px; padding: 0px" id="_tp_nzwasrngqcllywgnexwh_output_5_name"
#     onclick="_output_onclick_nzwasrngqcllywgnexwh(5)"
#     onmouseover="_output_onmouseover_nzwasrngqcllywgnexwh(5, this);">FR</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 0.9921172509407804); border-radius: 3px; padding: 0px" id="_tp_nzwasrngqcllywgnexwh_output_6_name"
#     onclick="_output_onclick_nzwasrngqcllywgnexwh(6)"
#     onmouseover="_output_onmouseover_nzwasrngqcllywgnexwh(6, this);">JP</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_nzwasrngqcllywgnexwh_output_7_name"
#     onclick="_output_onclick_nzwasrngqcllywgnexwh(7)"
#     onmouseover="_output_onmouseover_nzwasrngqcllywgnexwh(7, this);">MX</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_nzwasrngqcllywgnexwh_output_8_name"
#     onclick="_output_onclick_nzwasrngqcllywgnexwh(8)"
#     onmouseover="_output_onmouseover_nzwasrngqcllywgnexwh(8, this);">US</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_nzwasrngqcllywgnexwh_output_9_name"
#     onclick="_output_onclick_nzwasrngqcllywgnexwh(9)"
#     onmouseover="_output_onmouseover_nzwasrngqcllywgnexwh(9, this);">ZA</div><br><br><div id='_tp_nzwasrngqcllywgnexwh_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="51.35999648076415%" y1="33" x2="51.35999648076415%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="51.35999648076415%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.0999</text><line x1="37.16448513511876%" y1="33" x2="37.16448513511876%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="37.16448513511876%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.0996</text><line x1="22.96897378947271%" y1="33" x2="22.96897378947271%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="22.96897378947271%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.0993</text><line x1="8.773462443827315%" y1="33" x2="8.773462443827315%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="8.773462443827315%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.099</text><line x1="65.55550782640954%" y1="33" x2="65.55550782640954%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="65.55550782640954%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.1002</text><line x1="79.75101917205559%" y1="33" x2="79.75101917205559%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="79.75101917205559%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.1005</text><line x1="63.09423905689031%" y1="33" x2="63.09423905689031%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="63.09423905689031%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.100148</text><text x="63.09423905689031%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.100148</text><text x="63.09423905689031%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line
# [('22, BULKARA ROAD, BELLEVUE HILL, NSW, 2023', 'MX', 0.10092790424823761), ('30, RUA BOM MILAGRE, São Luís, MA, 65000-000', 'MX', 0.10092788934707642), ('193, STAFFORD DRIVE, Wheeling, 60090', 'MX', 0.10092790424823761), ('2375-3, 周東町上久原', 'MX', 0.10092790424823761), ('35, CL CANCHUELA, 5400', 'MX', 0.10092790424823761)]

# %% [markdown]
# In the plot above, we can see the explanation for that multiple instances selected one below the other, as well the predicted class for each input instance listed in the final output shown.

# %% [markdown]
# ## Model metrics
#
# To get a sense of how well the model is trained, we will calculate some important metrics for our `text-classifier` model. First, to find how accurate[[2]](#References) the model is in correctly predicting the classes in the dataset, we will call the model's `accuracy()` method.

# %%
model.accuracy()
# Out:
# 0.99

# %% [markdown]
# Other important metrics to look at are Precision, Recall & F1-measures [[3]](#References). To find `precision`, `recall` & `f1` scores per label/class we will call the model's `metrics_per_label()` method.

# %%
model.metrics_per_label()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='9998' class='' max='9998' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [9998/9998 02:32<00:00]
#     </div>
#     Precision_score  Recall_score  F1_score  Support
# AU           1.0000        1.0000    1.0000   1000.0
# BE           0.9990        0.9990    0.9990   1000.0
# BR           1.0000        1.0000    1.0000   1000.0
# CA           0.9373        0.9710    0.9538   1000.0
# ES           0.9990        1.0000    0.9995   1000.0
# FR           0.9990        0.9990    0.9990   1000.0
# JP           1.0000        1.0000    1.0000   1000.0
# MX           0.9990        1.0000    0.9995   1000.0
# US           0.9698        0.9329    0.9510    998.0
# ZA           1.0000        1.0000    1.0000   1000.0

# %% [markdown]
# ## Get misclassified records
#
# Its always a good idea to see the cases where your model is not performing well. This step will help us to:
# - Identify if there is a problem in the dataset.
# - Identify if there is a problem with text/documents belonging to a specific label/class.
# - Identify if there is a class imbalance in your dataset, due to which the model didn't see much of the labeled data for a particular class, hence not able to learn properly about that class.
#
# To get the **misclassified records** we will call the model's `get_misclassified_records` method.

# %%
misclassified_records = model.get_misclassified_records()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='9998' class='' max='9998' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [9998/9998 02:31<00:00]
#     </div>

# %%
Counter(misclassified_records["Prediction"])
# Out:
# Counter({'CA': 65, 'US': 29, 'FR': 1, 'BE': 1, 'ES': 1, 'MX': 1})

# %%
Counter(misclassified_records["Target"])
# Out:
# Counter({'US': 67, 'CA': 29, 'FR': 1, 'BE': 1})

# %% [markdown]
# ## Saving the trained model
#
# Once you are satisfied with the model, you can save it using the save() method. This creates an Esri Model Definition (EMD file) that can be used for inferencing on unseen data.

# %%
model.save("country-classifier-17thfeb-xlm -acc99")
# Out:
# Computing model metrics...
# WindowsPath('C:/Users/kaj13232/Documents/Work/NLP Notebook Samples/models/country-classifier-17thfeb-xlmroberta-acc99')

# %% [markdown]
# # Model inference
#
# The trained model can be used to classify new text documents using the predict method. This method accepts a string or a list of strings to predict the labels of these new documents/text.

# %%
text_list = data._train_df.sample(15).Address.values
result = model.predict(text_list)

df = pd.DataFrame(result, columns=["Address", "CountryCode", "Confidence"])

df.style.set_table_styles([dict(selector='th', props=[('text-align', 'left')])])\
        .set_properties(**{'text-align': "left"}).hide_index()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='15' class='' max='15' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [15/15 00:00<00:00]
#     </div>
# this method is deprecated in favour of `Styler.hide(axis='index')`
# <style type="text/css">
# #T_1a0d2 th {
#   text-align: left;
# }
# #T_1a0d2_row0_col0, #T_1a0d2_row0_col1, #T_1a0d2_row0_col2, #T_1a0d2_row1_col0, #T_1a0d2_row1_col1, #T_1a0d2_row1_col2, #T_1a0d2_row2_col0, #T_1a0d2_row2_col1, #T_1a0d2_row2_col2, #T_1a0d2_row3_col0, #T_1a0d2_row3_col1, #T_1a0d2_row3_col2, #T_1a0d2_row4_col0, #T_1a0d2_row4_col1, #T_1a0d2_row4_col2, #T_1a0d2_row5_col0, #T_1a0d2_row5_col1, #T_1a0d2_row5_col2, #T_1a0d2_row6_col0, #T_1a0d2_row6_col1, #T_1a0d2_row6_col2, #T_1a0d2_row7_col0, #T_1a0d2_row7_col1, #T_1a0d2_row7_col2, #T_1a0d2_row8_col0, #T_1a0d2_row8_col1, #T_1a0d2_row8_col2, #T_1a0d2_row9_col0, #T_1a0d2_row9_col1, #T_1a0d2_row9_col2, #T_1a0d2_row10_col0, #T_1a0d2_row10_col1, #T_1a0d2_row10_col2, #T_1a0d2_row11_col0, #T_1a0d2_row11_col1, #T_1a0d2_row11_col2, #T_1a0d2_row12_col0, #T_1a0d2_row12_col1, #T_1a0d2_row12_col2, #T_1a0d2_row13_col0, #T_1a0d2_row13_col1, #T_1a0d2_row13_col2, #T_1a0d2_row14_col0, #T_1a0d2_row14_col1, #T_1a0d2_row14_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_1a0d2">
#   <thead>
#     <tr>
#       <th id="T_1a0d2_level0_col0" class="col_heading level0 col0" >Address</th>
#       <th id="T_1a0d2_level0_col1" class="col_heading level0 col1" >CountryCode</th>
#       <th id="T_1a0d2_level0_col2" class="col_heading level0 col2" >Confidence</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_1a0d2_row0_col0" class="data row0 col0" >SN, COSTA  MARATAUIRA 2, Abaetetuba, PA, 68440-000</td>
#       <td id="T_1a0d2_row0_col1" class="data row0 col1" >MX</td>
#       <td id="T_1a0d2_row0_col2" class="data row0 col2" >0.100928</td>
#     </tr>
#     <tr>
#       <td id="T_1a0d2_row1_col0" class="data row1 col0" >365-9, 正能</td>
#       <td id="T_1a0d2_row1_col1" class="data row1 col1" >MX</td>
#       <td id="T_1a0d2_row1_col2" class="data row1 col2" >0.100928</td>
#     </tr>
#     <tr>
#       <td id="T_1a0d2_row2_col0" class="data row2 col0" >3966, NAVARRE AVE, OREGON, LUC, OH, 43616</td>
#       <td id="T_1a0d2_row2_col1" class="data row2 col1" >MX</td>
#       <td id="T_1a0d2_row2_col2" class="data row2 col2" >0.100928</td>
#     </tr>
#     <tr>
#       <td id="T_1a0d2_row3_col0" class="data row3 col0" >1300, Yates ST, 106</td>
#       <td id="T_1a0d2_row3_col1" class="data row3 col1" >MX</td>
#       <td id="T_1a0d2_row3_col2" class="data row3 col2" >0.100928</td>
#     </tr>
#     <tr>
#       <td id="T_1a0d2_row4_col0" class="data row4 col0" >15, Peer Street, De Aar, Emthanjeni</td>
#       <td id="T_1a0d2_row4_col1" class="data row4 col1" >MX</td>
#       <td id="T_1a0d2_row4_col2" class="data row4 col2" >0.100928</td>
#     </tr>
#     <tr>
#       <td id="T_1a0d2_row5_col0" class="data row5 col0" >3846, MEADOWLARK RD, ROANOKE, Roanoke County, VA, 24018</td>
#       <td id="T_1a0d2_row5_col1" class="data row5 col1" >MX</td>
#       <td id="T_1a0d2_row5_col2" class="data row5 col2" >0.100928</td>
#     </tr>
#     <tr>
#       <td id="T_1a0d2_row6_col0" class="data row6 col0" >2, KAILUA WAY, DILLON BEACH, 94929</td>
#       <td id="T_1a0d2_row6_col1" class="data row6 col1" >MX</td>
#       <td id="T_1a0d2_row6_col2" class="data row6 col2" >0.100928</td>
#     </tr>
#     <tr>
#       <td id="T_1a0d2_row7_col0" class="data row7 col0" >37, CALLE PARQUESITO, TARIMORO, Tarimoro, Guanajuato</td>
#       <td id="T_1a0d2_row7_col1" class="data row7 col1" >MX</td>
#       <td id="T_1a0d2_row7_col2" class="data row7 col2" >0.100928</td>
#     </tr>
#     <tr>
#       <td id="T_1a0d2_row8_col0" class="data row8 col0" >36, Green Maple Drive, St. Catharines, L2P3P9</td>
#       <td id="T_1a0d2_row8_col1" class="data row8 col1" >MX</td>
#       <td id="T_1a0d2_row8_col2" class="data row8 col2" >0.100928</td>
#     </tr>
#     <tr>
#       <td id="T_1a0d2_row9_col0" class="data row9 col0" >2, Allée des Bengalis, Pessac, 33600</td>
#       <td id="T_1a0d2_row9_col1" class="data row9 col1" >MX</td>
#       <td id="T_1a0d2_row9_col2" class="data row9 col2" >0.100928</td>
#     </tr>
#     <tr>
#       <td id="T_1a0d2_row10_col0" class="data row10 col0" >751-9, 高</td>
#       <td id="T_1a0d2_row10_col1" class="data row10 col1" >MX</td>
#       <td id="T_1a0d2_row10_col2" class="data row10 col2" >0.100928</td>
#     </tr>
#     <tr>
#       <td id="T_1a0d2_row11_col0" class="data row11 col0" >225, KwaGuqa, Emalahleni</td>
#       <td id="T_1a0d2_row11_col1" class="data row11 col1" >MX</td>
#       <td id="T_1a0d2_row11_col2" class="data row11 col2" >0.100928</td>
#     </tr>
#     <tr>
#       <td id="T_1a0d2_row12_col0" class="data row12 col0" >9233, OLD A1A, SAINT AUGUSTINE, ST_JOHNS, FL, 32080</td>
#       <td id="T_1a0d2_row12_col1" class="data row12 col1" >MX</td>
#       <td id="T_1a0d2_row12_col2" class="data row12 col2" >0.100928</td>
#     </tr>
#     <tr>
#       <td id="T_1a0d2_row13_col0" class="data row13 col0" >608-9, 東長沼</td>
#       <td id="T_1a0d2_row13_col1" class="data row13 col1" >MX</td>
#       <td id="T_1a0d2_row13_col2" class="data row13 col2" >0.100928</td>
#     </tr>
#     <tr>
#       <td id="T_1a0d2_row14_col0" class="data row14 col0" >33, Midrand, City of Johannesburg</td>
#       <td id="T_1a0d2_row14_col1" class="data row14 col1" >MX</td>
#       <td id="T_1a0d2_row14_col2" class="data row14 col2" >0.100928</td>
#     </tr>
#   </tbody>
# </table>

# %%
Counter(data._train_df["Country"])
# Out:
# Counter({'ES': 9000,
#          'FR': 9000,
#          'BR': 9000,
#          'MX': 9000,
#          'AU': 9000,
#          'ZA': 9000,
#          'CA': 9000,
#          'JP': 9000,
#          'BE': 9000,
#          'US': 8995})

# %% [markdown]
# # Conclusion

# %% [markdown]
# In this notebook, we have built a text classifier using `TextClassifier` class of `arcgis.learn.text` module. The dataset consisted of house addresses of 10 countries written in languages like English, Japanese, French, Spanish, etc. To achieve this we used a [multi-lingual transformer backbone](https://huggingface.co/transformers/v3.0.2/multilingual.html) like `XLM-RoBERTa` to build a classifier to predict the country for an input house address. We also implemented model explainability to understand how predictions for each row are made.

# %% [markdown]
# # References

# %% [markdown]
# [1] [Learning Rate](https://en.wikipedia.org/wiki/Learning_rate)
#
# [2] [Accuracy](https://en.wikipedia.org/wiki/Accuracy_and_precision)
#
# [3] [Precision, recall and F1-measures](https://scikit-learn.org/stable/modules/model_evaluation.html#precision-recall-and-f-measures)
