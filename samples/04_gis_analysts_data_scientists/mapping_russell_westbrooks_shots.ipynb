# %% [markdown]
# # Shotcharts Revisited - From NBA Stats to Feature Service in  Less Than 20 Lines of Code!
#
# About two years ago, I wrote about [creating shotcharts in ArcGIS using python and arcpy](https://gavinr.com/2015/11/04/geography-basketball-mapping-nba-shotcharts-arcgis/). In the post, I demonstrated how to scrape the data from [stats.nba.com](http://stats.nba.com/) and create a "shots" feature class from the data. I then shared the resulting shot chart as several web maps in ArcGIS Online.
#
# What I was unable to do at the time was automate the creation of the feature service and web maps that I shared in that post. Recent enhancements to the ArcGIS API for Python (https://developers.arcgis.com/python/) allow me to automate the process of sharing the "shot" data as a hosted feature service in ArcGIS Online and design web maps using the "shot" data. What I really like is that I can do this with very minimal code! In my precious post, I had to scrape the shot data, create a feature class, add fields to the feature class, and then add the shot data to the feature class. At that point, I would manually create a hosted feature service from the shot feature class. With recent enhancements to the ArcGIS Python API,I can do this all in Python and I can to this in less than 20 lines of code! In this post, I will demonstrate how to to scape data from the NBA statistics site, put it into a spatial dataframe, share the spatial dataframe as a hosted feature service, and design web maps that use the hosted feature service. I will try to do this in as little code as  possible!
#
# ## Python Packages
#
# In this post, I will use the ArcGIS Python API, pandas, and requests. I will log into my ArcGIS Online account in order to save the shot data to a hosted feature service.

# %%
import arcgis
from arcgis.gis import GIS
from arcgis.features import SpatialDataFrame

import pandas as pd
import requests

from IPython.display import display

gis = GIS("https://www.arcgis.com", "username")
# Out:
# Enter password: ········

# %% [markdown]
# ## Getting the Shot Data
#
# In my [original post](https://gavinr.com/2015/11/04/geography-basketball-mapping-nba-shotcharts-arcgis/) I looked at shots taken by Russell Westbrook from the 2014-2015 regular season. Here I will look at Russell Westbrook's shots taken during the 2016-2017 regular season. I also showed how to do this with "urllib." Here, I will use requests similar to how Savvas Tjortjoglou does in [How to Create NBA Shot Charts in Python](http://savvastjortjoglou.com/nba-shot-sharts.html).

# %%
player_id= '201566' #Russell Westbrook
season = '2016-17'  #MVP Season of 2016-17
seasontype="Regular+Season" #or use "Playoffs" for shots taken in playoffs

# %% [markdown]
# I will form the NBA stats request URL using Russell Westbrook's NBA.com player ID and use requests to get the data.

# %%
nba_call_url = 'http://stats.nba.com/stats/shotchartdetail?AheadBehind=&CFID=&CFPARAMS=&ClutchTime=&Conference=&ContextFilter=&ContextMeasure=FGM&DateFrom=&DateTo=&Division=&EndPeriod=10&EndRange=28800&GameEventID=&GameID=&GameSegment=&GroupID=&GroupQuantity=5&LastNGames=0&LeagueID=00&Location=&Month=0&OpponentTeamID=0&Outcome=&PORound=0&Period=0&PlayerID=%s&PlayerPosition=&PointDiff=&Position=&RangeType=0&RookieYear=&Season=%s&SeasonSegment=&SeasonType=%s&ShotClockRange=&StartPeriod=1&StartRange=0&StarterBench=&TeamID=0&VsConference=&VsDivision=' % (player_id, season, seasontype)
response = requests.get(nba_call_url, headers={'User-Agent': "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/48.0.2564.82 Safari/537.36"})

# %% [markdown]
# I will push the response JSON into a pandas dataframe.

# %%
shots = response.json()['resultSets'][0]['rowSet']
headers = response.json()['resultSets'][0]['headers']
shot_df = pd.DataFrame(shots, columns=headers)

# %%
shot_df
# Out:
#               GRID_TYPE     GAME_ID  GAME_EVENT_ID  PLAYER_ID
Russell Westbrook  1610612760  Oklahoma City Thunder       1
# 1     Russell Westbrook  1610612760  Oklahoma City Thunder       1
# 2     Russell Westbrook  1610612760  Oklahoma City Thunder       1
# 3     Russell Westbrook  1610612760  Oklahoma City Thunder       1
# 4     Russell Westbrook  1610612760  Oklahoma City Thunder       1
# 5     Russell Westbrook  1610612760  Oklahoma City Thunder       1
# 6     Russell Westbrook  1610612760  Oklahoma City Thunder       1
# 7     Russell Westbrook  1610612760  Oklahoma City Thunder       2
# 8     Russell Westbrook  1610612760  Oklahoma City Thunder       2
# 9     Russell Westbrook  1610612760  Oklahoma City Thunder       2
# 10    Russell Westbrook  1610612760  Oklahoma City Thunder       2
# 11    Russell Westbrook  1610612760  Oklahoma City Thunder       3
# 12    Russell Westbrook  1610612760  Oklahoma City Thunder       3
# 13    Russell Westbrook  1610612760  Oklahoma City Thunder       3
# 14    Russell Westbrook  1610612760  Oklahoma City Thunder       3
# 15    Russell Westbrook  1610612760  Oklahoma City Thunder       4
# 16    Russell Westbrook  1610612760  Oklahoma City Thunder       4
# 17    Russell Westbrook  1610612760  Oklahoma City Thunder       4
# 18    Russell Westbrook  1610612760  Oklahoma City Thunder       4
# 19    Russell Westbrook  1610612760  Oklahoma City Thunder       4
# 20    Russell Westbrook  1610612760  Oklahoma City Thunder       4
# 21    Russell Westbrook  1610612760  Oklahoma City Thunder       1
# 22    Russell Westbrook  1610612760  Oklahoma City Thunder       1
# 23    Russell Westbrook  1610612760  Oklahoma City Thunder       1
# 24    Russell Westbrook  1610612760  Oklahoma City Thunder       1
# 25    Russell Westbrook  1610612760  Oklahoma City Thunder       1
# 26    Russell Westbrook  1610612760  Oklahoma City Thunder       1
# 27    Russell Westbrook  1610612760  Oklahoma City Thunder       1
# 28    Russell Westbrook  1610612760  Oklahoma City Thunder       2
# 29    Russell Westbrook  1610612760  Oklahoma City Thunder       2
# ...                 ...         ...                    ...     ...
# 1911  Russell Westbrook  1610612760  Oklahoma City Thunder       2
# 1912  Russell Westbrook  1610612760  Oklahoma City Thunder       2
# 1913  Russell Westbrook  1610612760  Oklahoma City Thunder       3
# 1914  Russell Westbrook  1610612760  Oklahoma City Thunder       3
# 1915  Russell Westbrook  1610612760  Oklahoma City Thunder       3
# 1916  Russell Westbrook  1610612760  Oklahoma City Thunder       3
# 1917  Russell Westbrook  1610612760  Oklahoma City Thunder       3
# 1918  Russell Westbrook  1610612760  Oklahoma City Thunder       3
# 1919  Russell Westbrook  1610612760  Oklahoma City Thunder       3
# 1920  Russell Westbrook  1610612760  Oklahoma City Thunder       3
# 1921  Russell Westbrook  1610612760  Oklahoma City Thunder       4
# 1922  Russell Westbrook  1610612760  Oklahoma City Thunder       4
# 1923  Russell Westbrook  1610612760  Oklahoma City Thunder       4
# 1924  Russell Westbrook  1610612760  Oklahoma City Thunder       4
# 1925  Russell Westbrook  1610612760  Oklahoma City Thunder       4
# 1926  Russell Westbrook  1610612760  Oklahoma City Thunder       4
# 1927  Russell Westbrook  1610612760  Oklahoma City Thunder       4
# 1928  Russell Westbrook  1610612760  Oklahoma City Thunder       4
# 1929  Russell Westbrook  1610612760  Oklahoma City Thunder       4
# 1930  Russell Westbrook  1610612760  Oklahoma City Thunder       4
# 1931  Russell Westbrook  1610612760  Oklahoma City Thunder       1
# 1932  Russell Westbrook  1610612760  Oklahoma City Thunder       1
# 1933  Russell Westbrook  1610612760  Oklahoma City Thunder       1
# 1934  Russell Westbrook  1610612760  Oklahoma City Thunder       1
# 1935  Russell Westbrook  1610612760  Oklahoma City Thunder       1
# 1936  Russell Westbrook  1610612760  Oklahoma City Thunder       1
# 1937  Russell Westbrook  1610612760  Oklahoma City Thunder       1
# 1938  Russell Westbrook  1610612760  Oklahoma City Thunder       2
# 1939  Russell Westbrook  1610612760  Oklahoma City Thunder       2
# 1940  Russell Westbrook  1610612760  Oklahoma City Thunder       2
#
#       MINUTES_REMAINING  SECONDS_REMAINING ...          SHOT_ZONE_AREA  \
# 0                    11                 43 ...           Right Side(R)
# 1                    10                  9 ...            Left Side(L)
# 2                     8                  1 ...               Center(C)
# 3                     7                  6 ...            Left Side(L)
# 4                     6                 16 ...               Center(C)
# 5                     4                 52 ...               Center(C)
# 6                     4                  1 ...            Left Side(L)
# 7                     4                 34 ...           Right Side(R)
# 8                     2                 22 ...            Left Side(L)
# 9                     1                 53 ...   Right Side Center(RC)
# 10                    0                 22 ...               Center(C)
# 11                   10                 25 ...               Center(C)
# 12                    8                  6 ...           Right Side(R)
# 13                    3                 42 ...               Center(C)
# 14                    3                  2 ...           Right Side(R)
# 15                    6                  1 ...               Center(C)
# 16                    5                 50 ...           Right Side(R)
# 17                    4                  9 ...               Center(C)
# 18                    2                 44 ...           Right Side(R)
# 19                    1                 36 ...               Center(C)
# 20                    1                  7 ...           Right Side(R)
# 21                   11                 13 ...               Center(C)
# 22                    8                 51 ...           Right Side(R)
# 23                    6                 45 ...               Center(C)
# 24                    6                 20 ...    Left Side Center(LC)
# 25                    5                 49 ...            Left Side(L)
# 26                    4                 34 ...           Right Side(R)
# 27                    3                 53 ...               Center(C)
# 28                    8                 12 ...               Center(C)
# 29                    7                 27 ...            Left Side(L)
# ...                 ...                ... ...                     ...
# 1911                  1                 46 ...   Right Side Center(RC)
# 1912                  1                 13 ...               Center(C)
# 1913                  8                 54 ...               Center(C)
# 1914                  8                 16 ...               Center(C)
# 1915                  7                 25 ...    Left Side Center(LC)
# 1916                  6                 16 ...   Right Side Center(RC)
# 1917                  5                 16 ...            Left Side(L)
# 1918                  4                 35 ...    Left Side Center(LC)
# 1919                  3                 36 ...               Center(C)
# 1920                  3                 10 ...            Left Side(L)
# 1921                  6                 20 ...               Center(C)
# 1922                  5                 17 ...               Center(C)
# 1923                  4                 49 ...   Right Side Center(RC)
# 1924                  3                 35 ...               Center(C)
# 1925                  2                 58 ...               Center(C)
# 1926                  2                 27 ...               Center(C)
# 1927                  1                 51 ...   Right Side Center(RC)
# 1928                  1                 33 ...    Left Side Center(LC)
# 1929                  0                 27 ...               Center(C)
# 1930                  0                  0 ...    Left Side Center(LC)
# 1931                 11                 16 ...   Right Side Center(RC)
# 1932                 10                 17 ...               Center(C)
# 1933                  8                  6 ...               Center(C)
# 1934                  5                  7 ...               Center(C)
# 1935                  4                 42 ...               Center(C)
# 1936                  4                  5 ...            Left Side(L)
# 1937                  3                 32 ...    Left Side Center(LC)
# 1938                  3                  9 ...           Right Side(R)
# 1939                  0                 51 ...   Right Side Center(RC)
# 1940                  0                  0 ...    Left Side Center(LC)
#
#       SHOT_ZONE_RANGE SHOT_DISTANCE LOC_X LOC_Y SHOT_ATTEMPTED_FLAG
HOT_MADE_FLAG  GAME_DATE  HTM  VTM
# 0                  0   20161026  PHI  OKC
# 1                  1   20161026  PHI  OKC
# 2                  0   20161026  PHI  OKC
# 3                  0   20161026  PHI  OKC
# 4                  1   20161026  PHI  OKC
# 5                  1   20161026  PHI  OKC
# 6                  1   20161026  PHI  OKC
# 7                  1   20161026  PHI  OKC
# 8                  1   20161026  PHI  OKC
# 9                  0   20161026  PHI  OKC
# 10                 0   20161026  PHI  OKC
# 11                 0   20161026  PHI  OKC
# 12                 1   20161026  PHI  OKC
# 13                 1   20161026  PHI  OKC
# 14                 0   20161026  PHI  OKC
# 15                 0   20161026  PHI  OKC
# 16                 0   20161026  PHI  OKC
# 17                 1   20161026  PHI  OKC
# 18                 1   20161026  PHI  OKC
# 19                 0   20161026  PHI  OKC
# 20                 1   20161026  PHI  OKC
# 21                 0   20161028  OKC  PHX
# 22                 0   20161028  OKC  PHX
# 23                 0   20161028  OKC  PHX
# 24                 0   20161028  OKC  PHX
# 25                 1   20161028  OKC  PHX
# 26                 0   20161028  OKC  PHX
# 27                 1   20161028  OKC  PHX
# 28                 1   20161028  OKC  PHX
# 29                 0   20161028  OKC  PHX
# ...              ...        ...  ...  ...
# 1911               1   20170409  DEN  OKC
# 1912               1   20170409  DEN  OKC
# 1913               0   20170409  DEN  OKC
# 1914               0   20170409  DEN  OKC
# 1915               1   20170409  DEN  OKC
# 1916               0   20170409  DEN  OKC
# 1917               0   20170409  DEN  OKC
# 1918               0   20170409  DEN  OKC
# 1919               1   20170409  DEN  OKC
# 1920               1   20170409  DEN  OKC
# 1921               0   20170409  DEN  OKC
# 1922               1   20170409  DEN  OKC
# 1923               0   20170409  DEN  OKC
# 1924               1   20170409  DEN  OKC
# 1925               0   20170409  DEN  OKC
# 1926               1   20170409  DEN  OKC
# 1927               0   20170409  DEN  OKC
# 1928               0   20170409  DEN  OKC
# 1929               1   20170409  DEN  OKC
# 1930               1   20170409  DEN  OKC
# 1931               0   20170412  OKC  DEN
# 1932               0   20170412  OKC  DEN
# 1933               0   20170412  OKC  DEN
# 1934               0   20170412  OKC  DEN
# 1935               0   20170412  OKC  DEN
# 1936               1   20170412  OKC  DEN
# 1937               0   20170412  OKC  DEN
# 1938               1   20170412  OKC  DEN
# 1939               0   20170412  OKC  DEN
# 1940               0   20170412  OKC  DEN
#
# [1941 rows x 24 columns]

# %% [markdown]
# ## From DataFrame to SpatialDataFrame
#
# In order to publish the shot data to ArcGIS Online as a shotchart, I will convert the pandas dataframe to an "arcgis"
# spatial dataframe. In addition to passing the "shot_df" to "SpatialDataFrame", I will pass the geometries associated with each row in the dataframe.

# %%
shot_coords = shot_df.iloc[:,17:19].values.tolist()
sdf = SpatialDataFrame(shot_df,geometry=[arcgis.geometry.Geometry({'x':-r[0], 'y':r[1], 
                    'spatialReference':{'wkid':3857}}) for r in shot_coords])

# %%
sdf
# Out:
#               GRID_TYPE     GAME_ID  GAME_EVENT_ID  PLAYER_
Russell Westbrook  1610612760  Oklahoma City Thunder       1
# 26    Russell Westbrook  1610612760  Oklahoma City Thunder       1
# 27    Russell Westbrook  1610612760  Oklahoma City Thunder       1
# 28    Russell Westbrook  1610612760  Oklahoma City Thunder       2
# 29    Russell Westbrook  1610612760  Oklahoma City Thunder       2
# ...                 ...         ...                    ...     ...
# 1911  Russell Westbrook  1610612760  Oklahoma City Thunder       2
# 1912  Russell Westbrook  1610612760  Oklahoma City Thunder       2
# 1913  Russell Westbrook  1610612760  Oklahoma City Thunder       3
# 1914  Russell Westbrook  1610612760  Oklahoma City Thunder       3
# 1915  Russell Westbrook  1610612760  Oklahoma City Thunder       3
# 1916  Russell Westbrook  1610612760  Oklahoma City Thunder       3
# 1917  Russell Westbrook  1610612760  Oklahoma City Thunder       3
# 1918  Russell Westbrook  1610612760  Oklahoma City Thunder       3
# 1919  Russell Westbrook  1610612760  Oklahoma City Thunder       3
# 1920  Russell Westbrook  1610612760  Oklahoma City Thunder       3
# 1921  Russell Westbrook  1610612760  Oklahoma City Thunder       4
# 1922  Russell Westbrook  1610612760  Oklahoma City Thunder       4
# 1923  Russell Westbrook  1610612760  Oklahoma City Thunder       4
# 1924  Russell Westbrook  1610612760  Oklahoma City Thunder       4
# 1925  Russell Westbrook  1610612760  Oklahoma City Thunder       4
# 1926  Russell Westbrook  1610612760  Oklahoma City Thunder       4
# 1927  Russell Westbrook  1610612760  Oklahoma City Thunder       4
# 1928  Russell Westbrook  1610612760  Oklahoma City Thunder       4
# 1929  Russell Westbrook  1610612760  Oklahoma City Thunder       4
# 1930  Russell Westbrook  1610612760  Oklahoma City Thunder       4
# 1931  Russell Westbrook  1610612760  Oklahoma City Thunder       1
# 1932  Russell Westbrook  1610612760  Oklahoma City Thunder       1
# 1933  Russell Westbrook  1610612760  Oklahoma City Thunder       1
# 1934  Russell Westbrook  1610612760  Oklahoma City Thunder       1
# 1935  Russell Westbrook  1610612760  Oklahoma City Thunder       1
# 1936  Russell Westbrook  1610612760  Oklahoma City Thunder       1
# 1937  Russell Westbrook  1610612760  Oklahoma City Thunder       1
# 1938  Russell Westbrook  1610612760  Oklahoma City Thunder       2
# 1939  Russell Westbrook  1610612760  Oklahoma City Thunder       2
# 1940  Russell Westbrook  1610612760  Oklahoma City Thunder       2
#
#       MINUTES_REMAINING  SECONDS_REMAINING  \
# 0                    11                 43
# 1                    10                  9
# 2                     8                  1
# 3                     7                  6
# 4                     6                 16
# 5                     4                 52
# 6                     4                  1
# 7                     4                 34
# 8                     2                 22
# 9                     1                 53
# 10                    0                 22
# 11                   10                 25
# 12                    8                  6
# 13                    3                 42
# 14                    3                  2
# 15                    6                  1
# 16                    5                 50
# 17                    4                  9
# 18                    2                 44
# 19                    1                 36
# 20                    1                  7
# 21                   11                 13
# 22                    8                 51
# 23                    6                 45
# 24                    6                 20
# 25                    5                 49
# 26                    4                 34
# 27                    3                 53
# 28                    8                 12
# 29                    7                 27
# ...                 ...                ...
# 1911                  1                 46
# 1912                  1                 13
# 1913                  8                 54
# 1914                  8                 16
# 1915                  7                 25
# 1916                  6                 16
# 1917                  5                 16
# 1918                  4                 35
# 1919                  3                 36
# 1920                  3                 10
# 1921                  6                 20
# 1922                  5                 17
# 1923                  4                 49
# 1924                  3                 35
# 1925                  2                 58
# 1926                  2                 27
# 1927                  1                 51
# 1928                  1                 33
# 1929                  0                 27
# 1930                  0                  0
# 1931                 11                 16
# 1932                 10                 17
# 1933                  8                  6
# 1934                  5                  7
# 1935                  4                 42
# 1936                  4                  5
# 1937                  3                 32
# 1938                  3                  9
# 1939                  0                 51
# 1940                  0                  0
#
#                             ...                          SHOT_ZONE_RANGE  \
# 0                           ...                                16-24 ft.
# 1                           ...                                 8-16 ft.
# 2                           ...                          Less Than 8 ft.
# 3                           ...                                16-24 ft.
# 4                           ...                          Less Than 8 ft.
# 5                           ...                          Less Than 8 ft.
# 6                           ...                                 8-16 ft.
# 7                           ...                                 8-16 ft.
# 8                           ...                                16-24 ft.
# 9                           ...                                16-24 ft.
# 10                          ...                          Less Than 8 ft.
# 11                          ...                                 8-16 ft.
# 12                          ...                                16-24 ft.
# 13                          ...                          Less Than 8 ft.
# 14                          ...                                16-24 ft.
# 15                          ...                                  24+ ft.
# 16                          ...                                 8-16 ft.
# 17                          ...                                  24+ ft.
# 18                          ...                                16-24 ft.
# 19                          ...                          Less Than 8 ft.
# 20                          ...                                16-24 ft.
# 21                          ...                          Less Than 8 ft.
# 22                          ...                                 8-16 ft.
# 23                          ...                          Less Than 8 ft.
# 24                          ...                                  24+ ft.
# 25                          ...                                 8-16 ft.
# 26                          ...                                 8-16 ft.
# 27                          ...                          Less Than 8 ft.
# 28                          ...                          Less Than 8 ft.
# 29                          ...                                16-24 ft.
# ...                         ...                                      ...
# 1911                        ...                                  24+ ft.
# 1912                        ...                          Less Than 8 ft.
# 1913                        ...                                 8-16 ft.
# 1914                        ...                                16-24 ft.
# 1915                        ...                                  24+ ft.
# 1916                        ...                                  24+ ft.
# 1917                        ...                                 8-16 ft.
# 1918                        ...                                  24+ ft.
# 1919                        ...                          Less Than 8 ft.
# 1920                        ...                                  24+ ft.
# 1921                        ...                          Less Than 8 ft.
# 1922                        ...                                  24+ ft.
# 1923                        ...                                  24+ ft.
# 1924                        ...                          Less Than 8 ft.
# 1925                        ...                                  24+ ft.
# 1926                        ...                          Less Than 8 ft.
# 1927                        ...                                  24+ ft.
# 1928                        ...                                  24+ ft.
# 1929                        ...                          Less Than 8 ft.
# 1930                        ...                                  24+ ft.
# 1931                        ...                                16-24 ft.
# 1932                        ...                          Less Than 8 ft.
# 1933                        ...                                 8-16 ft.
# 1934                        ...                          Less Than 8 ft.
# 1935                        ...                                  24+ ft.
# 1936                        ...                                  24+ ft.
# 1937                        ...                                  24+ ft.
# 1938                        ...                                 8-16 ft.
# 1939                        ...                                  24+ ft.
# 1940                        ...                                  24+ ft.
#
#      SHOT_DISTANCE LOC_X LOC_Y SHOT_ATTEMPTED_FLAG SHOT_MADE_FLAG  GAME_DATE  \
# 0               17   174    36                   1              0   20161026
# 1               14  -117    87                   1              1   20161026
# 2                6   -58    36                   1              0   20161026
# 3               19  -183    80                   1              0   20161026
# 4                2   -20    -6                   1              1   20161026
# 5                1     9     7                   1              1   20161026
# 6               15  -151     3                   1              1   20161026
# 7               13   112    70                   1              1   20161026
# 8               18  -184     0                   1              1   20161026
# 9               16   114   126                   1              0   20161026
# 10               1    15     8                   1              0   20161026
# 11              12    -2   126                   1              0   20161026
# 12              16   163    13                   1              1   20161026
# 13               0     0     1                   1              1   20161026
# 14              16   151    75                   1              0   20161026
# 15              26    14   262                   1              0   20161026
# 16              11   102    56                   1              0   20161026
# 17              25   -19   257                   1              1   20161026
# 18              16   156    46                   1              1   20161026
# 19               1   -12     2                   1              0   20161026
# 20              17   174     2                   1              1   20161026
# 21               1    10    -1                   1              0   20161028
# 22              11    99    65                   1              0   20161028
# 23               1    -9    -5                   1              0   20161028
# 24              24  -142   198                   1              0   20161028
# 25              12  -102    75                   1              1   20161028
# 26               8    71    41                   1              0   20161028
# 27               0    -1     2                   1              1   20161028
# 28               0     9     3                   1              1   20161028
# 29              16  -148    70                   1              0   20161028
# ...            ...   ...   ...                 ...            ...        ...
# 1911            25   182   178                   1              1   20170409
# 1912             3   -30     2                   1              1   20170409
# 1913            14     1   149                   1              0   20170409
# 1914            19    -7   190                   1              0   20170409
# 1915            24  -151   190                   1              1   20170409
# 1916            26   158   208                   1              0   20170409
# 1917            14  -137    47                   1              0   20170409
# 1918            30  -186   247                   1              0   20170409
# 1919             3   -32    11                   1              1   20170409
# 1920            24  -240     8                   1              1   20170409
# 1921             0     0     1                   1              0   20170409
# 1922            26   -30   267                   1              1   20170409
# 1923            25   186   174                   1              0   20170409
# 1924             2    15    18                   1              1   20170409
# 1925            26   -58   262                   1              0   20170409
# 1926             1    12    11                   1              1   20170409
# 1927            24   202   136                   1              0   20170409
# 1928            25  -197   169                   1              0   20170409
# 1929             2   -25    16                   1              1   20170409
# 1930            35  -212   287                   1              1   20170409
# 1931            16   119   115                   1              0   20170412
# 1932             7    42    61                   1              0   20170412
# 1933            14    55   139                   1              0   20170412
# 1934             3    -3    32                   1              0   20170412
# 1935            25   -53   247                   1              0   20170412
# 1936            23  -225    67                   1              1   20170412
# 1937            26  -181   190                   1              0   20170412
# 1938            13   117    75                   1              1   20170412
# 1939            27   120   247                   1              0   20170412
# 1940            29  -130   269                   1              0   20170412
#
#       HTM  VTM                                              SHAPE
# 0     PHI  OKC  {'x': -174, 'y': 36, 'spatialReference': {'wki...
# 1     PHI  OKC  {'x': 117, 'y': 87, 'spatialReference': {'wkid...
# 2     PHI  OKC  {'x': 58, 'y': 36, 'spatialReference': {'wkid'...
# 3     PHI  OKC  {'x': 183, 'y': 80, 'spatialReference': {'wkid...
# 4     PHI  OKC  {'x': 20, 'y': -6, 'spatialReference': {'wkid'...
# 5     PHI  OKC  {'x': -9, 'y': 7, 'spatialReference': {'wkid':...
# 6     PHI  OKC  {'x': 151, 'y': 3, 'spatialReference': {'wkid'...
# 7     PHI  OKC  {'x': -112, 'y': 70, 'spatialReference': {'wki...
# 8     PHI  OKC  {'x': 184, 'y': 0, 'spatialReference': {'wkid'...
# 9     PHI  OKC  {'x': -114, 'y': 126, 'spatialReference': {'wk...
# 10    PHI  OKC  {'x': -15, 'y': 8, 'spatialReference': {'wkid'...
# 11    PHI  OKC  {'x': 2, 'y': 126, 'spatialReference': {'wkid'...
# 12    PHI  OKC  {'x': -163, 'y': 13, 'spatialReference': {'wki...
# 13    PHI  OKC  {'x': 0, 'y': 1, 'spatialReference': {'wkid': ...
# 14    PHI  OKC  {'x': -151, 'y': 75, 'spatialReference': {'wki...
# 15    PHI  OKC  {'x': -14, 'y': 262, 'spatialReference': {'wki...
# 16    PHI  OKC  {'x': -102, 'y': 56, 'spatialReference': {'wki...
# 17    PHI  OKC  {'x': 19, 'y': 257, 'spatialReference': {'wkid...
# 18    PHI  OKC  {'x': -156, 'y': 46, 'spatialReference': {'wki...
# 19    PHI  OKC  {'x': 12, 'y': 2, 'spatialReference': {'wkid':...
# 20    PHI  OKC  {'x': -174, 'y': 2, 'spatialReference': {'wkid...
# 21    OKC  PHX  {'x': -10, 'y': -1, 'spatialReference': {'wkid...
# 22    OKC  PHX  {'x': -99, 'y': 65, 'spatialReference': {'wkid...
# 23    OKC  PHX  {'x': 9, 'y': -5, 'spatialReference': {'wkid':...
# 24    OKC  PHX  {'x': 142, 'y': 198, 'spatialReference': {'wki...
# 25    OKC  PHX  {'x': 102, 'y': 75, 'spatialReference': {'wkid...
# 26    OKC  PHX  {'x': -71, 'y': 41, 'spatialReference': {'wkid...
# 27    OKC  PHX  {'x': 1, 'y': 2, 'spatialReference': {'wkid': ...
# 28    OKC  PHX  {'x': -9, 'y': 3, 'spatialReference': {'wkid':...
# 29    OKC  PHX  {'x': 148, 'y': 70, 'spatialReference': {'wkid...
# ...   ...  ...                                                ...
# 1911  DEN  OKC  {'x': -182, 'y': 178, 'spatialReference': {'wk...
# 1912  DEN  OKC  {'x': 30, 'y': 2, 'spatialReference': {'wkid':...
# 1913  DEN  OKC  {'x': -1, 'y': 149, 'spatialReference': {'wkid...
# 1914  DEN  OKC  {'x': 7, 'y': 190, 'spatialReference': {'wkid'...
# 1915  DEN  OKC  {'x': 151, 'y': 190, 'spatialReference': {'wki...
# 1916  DEN  OKC  {'x': -158, 'y': 208, 'spatialReference': {'wk...
# 1917  DEN  OKC  {'x': 137, 'y': 47, 'spatialReference': {'wkid...
# 1918  DEN  OKC  {'x': 186, 'y': 247, 'spatialReference': {'wki...
# 1919  DEN  OKC  {'x': 32, 'y': 11, 'spatialReference': {'wkid'...
# 1920  DEN  OKC  {'x': 240, 'y': 8, 'spatialReference': {'wkid'...
# 1921  DEN  OKC  {'x': 0, 'y': 1, 'spatialReference': {'wkid': ...
# 1922  DEN  OKC  {'x': 30, 'y': 267, 'spatialReference': {'wkid...
# 1923  DEN  OKC  {'x': -186, 'y': 174, 'spatialReference': {'wk...
# 1924  DEN  OKC  {'x': -15, 'y': 18, 'spatialReference': {'wkid...
# 1925  DEN  OKC  {'x': 58, 'y': 262, 'spatialReference': {'wkid...
# 1926  DEN  OKC  {'x': -12, 'y': 11, 'spatialReference': {'wkid...
# 1927  DEN  OKC  {'x': -202, 'y': 136, 'spatialReference': {'wk...
# 1928  DEN  OKC  {'x': 197, 'y': 169, 'spatialReference': {'wki...
# 1929  DEN  OKC  {'x': 25, 'y': 16, 'spatialReference': {'wkid'...
# 1930  DEN  OKC  {'x': 212, 'y': 287, 'spatialReference': {'wki...
# 1931  OKC  DEN  {'x': -119, 'y': 115, 'spatialReference': {'wk...
# 1932  OKC  DEN  {'x': -42, 'y': 61, 'spatialReference': {'wkid...
# 1933  OKC  DEN  {'x': -55, 'y': 139, 'spatialReference': {'wki...
# 1934  OKC  DEN  {'x': 3, 'y': 32, 'spatialReference': {'wkid':...
# 1935  OKC  DEN  {'x': 53, 'y': 247, 'spatialReference': {'wkid...
# 1936  OKC  DEN  {'x': 225, 'y': 67, 'spatialReference': {'wkid...
# 1937  OKC  DEN  {'x': 181, 'y': 190, 'spatialReference': {'wki...
# 1938  OKC  DEN  {'x': -117, 'y': 75, 'spatialReference': {'wki...
# 1939  OKC  DEN  {'x': -120, 'y': 247, 'spatialReference': {'wk...
# 1940  OKC  DEN  {'x': 130, 'y': 269, 'spatialReference': {'wki...
#
# [1941 rows x 25 columns]

# %% [markdown]
# ## From SpatialDataFrame to Service
#
# Now that the shots are in a spatial dataframe, I will publish them to ArcGIS Online.

# %%
shot_chart = gis.content.import_data(sdf)

# %% [markdown]
# Voila! I have the shots as a hosted feature service! It took less than 20 lines of code (including "import" statements) and to go from the NBA stats response to a hosted feature service only took 7 lines!

# %%
display(shot_chart)
# Out:
# <Item title:"1e5ea5c12d1b43cf9bb0af7747ece6f9" type:Feature Layer Collection owner:gregbrunner_dbs>

# %% [markdown]
# ## From Service to Web Maps
#
# Even though we have the shots as a feature service, we are not done. We can use the Python API to visualize the shots. Using the API for Python will create three maps. One that shows the shots without any renderer. One the that shows the shots symbolized by whether it was made or missed. And one that shows all the shots taken as a heatmap.
#
# For the basketball court, I will use the court feature class that I have in ArcGIS Online.

# %%
court_tiles = gis.content.search("Basketball Court", outside_org=False, item_type="Feature")
court_layers = court_tiles[1].layers
court_tiles
# Out:
# [<Item title:"Basketball_Court" type:Feature Layer Collection owner:gregbrunner_dbs>,
#  <Item title:"Basketball Court Feature Layers" type:Feature Layer Collection owner:gregbrunner_dbs>]

# %% [markdown]
# The court is broken into two feature services: One for the court outline and one for the court lines. I need to add them separately to the web map.
#
# ## Shot Locations

# %% [markdown]
# Now that I have the basketball court layers and the shots as a feature service, I can display them on my map. I will set the shot chart renderer to "None" in order so that the default point symbology is applied to the "shot_chart" layer.

# %%
chart1 = gis.map((0.002,0), zoomlevel=17)
display(chart1)

# %%
chart1.add_layer(court_layers[1])
chart1.basemap='dark-gray'

# %%
chart1.add_layer(court_layers[0])
chart1.add_layer(shot_chart,{"renderer":"None"})

# %% [markdown]
# ## Shots Made and Missed
#
# I want to be able to differentiate between shots made and shots missed. I can do that by changing the renderer when I add the "shot_chart" layer to the map. I will use the "ClassedColorRenderer" and apply the class colors based on the values in the "SHOT_MADE_FLAG" field.

# %%
chart2 = gis.map((0.002,0), zoomlevel=17)
display(chart2)

# %%
chart2.add_layer(court_layers[1])
chart2.basemap='dark-gray'

# %%
chart2.add_layer(court_layers[0])
chart2.add_layer(shot_chart, {"renderer":"ClassedColorRenderer",
               "field_name": "SHOT_MADE_FLAG"})

# %% [markdown]
# Shots missed are in dark gray. Shots made are in white. I assume that this is the default "ClassedColorRenderer". I need to do some more investigating to figure out how to apply my desired color map.

# %% [markdown]
# ## Shots Taken as a Heat Map
#
# I also want to see the shots taken as a heat map. I will use the "HeatmapRenderer" to do that.

# %%
chart3 = gis.map((0.002,0), zoomlevel=17)
display(chart3)

# %%
chart3.add_layer(court_layers[1])
chart3.basemap='dark-gray'

# %%
chart3.add_layer(court_layers[0])
chart3.add_layer(shot_chart, {"renderer":"HeatmapRenderer",
               "opacity": 0.75})

# %% [markdown]
# ## Analysis - Interpolation with EBK

# %% [markdown]
# I can also make a shooting percentage surface Using [Empirical Bayesian Kriging](http://desktop.arcgis.com/en/arcmap/10.3/guide-books/extensions/geostatistical-analyst/what-is-empirical-bayesian-kriging-.htm). This will effectively show me what Russell Westbrook's shooting percentage is across the basketball court. To do this, I must import *interpolate_points*.

# %%
from arcgis.features.analyze_patterns import interpolate_points

# %% [markdown]
# Next, I will run the tool on the *shot_chat* data specifying the 'SHOT_MADE_FLAG' as the field whose value I want to interpolate.

# %%
interpolated_shots = interpolate_points(shot_chart, field='SHOT_MADE_FLAG')

# %% [markdown]
# When the tool is finished, I will add the surface back to *chart2* so that I can see the surface along with the original points.

# %%
chart2.add_layer(interpolated_shots['result_layer'])
